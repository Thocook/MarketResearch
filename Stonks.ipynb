# %% [markdown]
# #Uploading TMX extraction of al tickers

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# Read the dataset from Google Drive, specifying the encoding as 'latin1' or 'ISO-8859-1'
dataset = pd.read_csv('/content/drive/MyDrive/###Your File Path###/tsx.csv', encoding='latin1')

# Drop the column named 'blank' from the dataset
dataset.drop(columns=['blank'], inplace=True)

# Drop rows with any missing values (NaN) and reset the index
dataset = dataset.dropna().reset_index(drop=True)

# Rename columns in the dataset
dataset.rename(columns={'blank 2': 'Ticker TMX', 'blank href': 'TMX Link', 'tablescraper-selected-row': 'Company'}, inplace=True)

# %%
dataset
# Out:
#                               tablescraper-selected-row  \
# 0                     A&W Revenue Royalties Income Fund
# 1                           Aberdeen International Inc-
# 2                    abrdn Asia-Pacific Income Fund VCC
# 3                                  Acadian Timber Corp-
# 4                 Accelerate Absolute Return Hedge Fund
# ...                                                 ...
# 2397  First Trust Value Line Dividend Index ETF (CAD...
# 2398   First Trust Vest U-S- Equity Buffer ETF - August
# 2399  First Trust Vest U-S- Equity Buffer ETF - Febr...
# 2400      First Trust Vest U-S- Equity Buffer ETF - May
# 2401  First Trust Vest U-S- Equity Buffer ETF - Nove...
#
#                                          blank href blank 2
# 0      https://money-tmx-com/en/quote/AW-UN/company   AW-UN
# 1        https://money-tmx-com/en/quote/AAB/company     AAB
# 2        https://money-tmx-com/en/quote/FAP/company     FAP
# 3        https://money-tmx-com/en/quote/ADN/company     ADN
# 4       https://money-tmx-com/en/quote/HDGE/company    HDGE
# ...                                             ...     ...
# 2397     https://money-tmx-com/en/quote/FUD/company     FUD
# 2398  https://money-tmx-com/en/quote/AUGB-F/company  AUGB-F
# 2399  https://money-tmx-com/en/quote/FEBB-F/company  FEBB-F
# 2400  https://money-tmx-com/en/quote/MAYB-F/company  MAYB-F
# 2401  https://money-tmx-com/en/quote/NOVB-F/company  NOVB-F
#
# [2402 rows x 3 columns]

# %%
# Refine to get just companies from the dataset by removing all Funds, ETFs, Trusts, and REITs.
filtered_df = dataset[~dataset['Company'].str.contains('Fund|ETF|Trust|REIT')]

# Reset the index of the filtered dataset
filtered_df = filtered_df.reset_index(drop=True)
filtered_df
# Out:
#                                   Company  \
# 0             Aberdeen International Inc-
# 1                    Acadian Timber Corp-
# 2                  Accord Financial Corp-
# 3                   Aclara Resources Inc-
# 4                             Adcore Inc-
# ..                                    ...
# 815                  Yellow Pages Limited
# 816                Yorbeau Resources Inc-
# 817    Sleep Country Canada Holdings Inc-
# 818                          5N Plus Inc-
# 819  First National Financial Corporation
#
#                                         TMX Link Ticker TMX   Ticker
# 0     https://money-tmx-com/en/quote/AAB/company        AAB   AAB.TO
# 1     https://money-tmx-com/en/quote/ADN/company        ADN   ADN.TO
# 2     https://money-tmx-com/en/quote/ACD/company        ACD   ACD.TO
# 3     https://money-tmx-com/en/quote/ARA/company        ARA   ARA.TO
# 4    https://money-tmx-com/en/quote/ADCO/company       ADCO  ADCO.TO
# ..                                           ...        ...      ...
# 815     https://money-tmx-com/en/quote/Y/company          Y     Y.TO
# 816   https://money-tmx-com/en/quote/YRB/company        YRB   YRB.TO
# 817   https://money-tmx-com/en/quote/ZZZ/company        ZZZ   ZZZ.TO
# 818   https://money-tmx-com/en/quote/VNP/company        VNP   VNP.TO
# 819    https://money-tmx-com/en/quote/FN/company         FN    FN.TO
#
# [820 rows x 4 columns]

# %% [markdown]
# #Cleaning Data

# %% [markdown]
#  First we get the ticker value from Yahoo to be used with yfinance. Doing so by searching for the company on Google with the ca.finance.yahoo.com type and then cleaning that returned dataset. The Google search and extraction is a lengthy process and therefore, the steps are **already done and the returning dataset is provided as the TSX_Companies.csv file**.

# %%
def extract_ticker_from_url(url):
    # First try to extract ticker using the original method Also make it capitalized.
    match = re.search(r"https://ca.finance.yahoo.com/quote/([^/.]+\.to)/?", url, re.IGNORECASE)
    if match:
        return match.group(1).str.upper()

    # If the original method fails, try the new method Also make it capitalized.
    match = re.search(r'quote/([^/]+)/?', url)
    if match:
        return match.group(1).str.upper()

    # If both methods fail, return None
    return None

# %%
# DOES NOT NEED TO BE RUN ON THE UPDATED DATA SET -> TSX_Companies.csv
## Was used to change tmx encoding to Yahooo encoding for tickers.
from googlesearch import search
import re

# Iterate through each row in the dataset
for index, row in filtered_df.iterrows():
    try:
        print(f"Processing row {index + 1}...")
        # Define the query for Google search
        query = f"{row['Company']} site:ca.finance.yahoo.com/quote"

        # Perform a Google search and get the URLs
        search_results = list(search(query, num=1, stop=1, pause=1))
        print(f"Search results for '{query}': {search_results}")

        # Extract the ticker from the first link
        if search_results:
            yahoo_finance_url = search_results[0]
            extracted_ticker = extract_ticker_from_url(yahoo_finance_url)
            print(f"extracted_ticker: {extracted_ticker}\n")
            # Update the 'Ticker' column in the DataFrame
            filtered_df.at[index, 'Ticker'] = extracted_ticker
    except Exception as e:
        print(f"Error processing row {index}: {e}")

# Print the updated dataset
print(filtered_df)
# Out:
# Processing row 1...
# Search results for 'Aberdeen International Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/AAB.TO/']
# extracted_ticker: AAB.TO
#
# Processing row 2...
# Search results for 'Acadian Timber Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ADN.TO/']
# extracted_ticker: ADN.TO
#
# Processing row 3...
# Search results for 'Accord Financial Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ACD.TO/']
# extracted_ticker: ACD.TO
#
# Processing row 4...
# Search results for 'Aclara Resources Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ARA.TO/']
# extracted_ticker: ARA.TO
#
# Processing row 5...
# Search results for 'Adcore Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ADCO.TO/']
# extracted_ticker: ADCO.TO
#
# Processing row 6...
# Search results for 'ADENTRA Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ADEN.TO/']
# extracted_ticker: ADEN.TO
#
# Processing row 7...
# Search results for 'ADF Group Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/DRX.TO/']
# extracted_ticker: DRX.TO
#
# Processing row 8...
# Search results for 'Advantage Energy Ltd- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/AAV.TO/']
# extracted_ticker: AAV.TO
#
# Processing row 9...
# Search results for 'Aecon Group Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ARE.TO/']
# extracted_ticker: ARE.TO
#
# Processing row 10...
# Search results for 'Aegis Brands Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/AEG.TO/']
# extracted_ticker: AEG.TO
#
# Processing row 11...
# Search results for 'AEterna Zentaris Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/AEZS.TO/']
# extracted_ticker: AEZS.TO
#
# Processing row 12...
# Search results for 'Africa Oil Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/AOI.TO/']
# extracted_ticker: AOI.TO
#
# Processing row 13...
# Search results for 'Ag Growth International Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/AFN.TO/']
# extracted_ticker: AFN.TO
#
# Processing row 14...
# Search results for 'AGF Management Limited site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/AGF-B.TO/']
# extracted_ticker: AGF-B.TO
#
# Processing row 15...
# Search results for 'Agnico Eagle Mines Limited site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/AEM.TO/']
# extracted_ticker: AEM.TO
#
# Processing row 16...
# Search results for 'Agrinam Acquisition Corporation site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/AGRI-U.TO/']
# extracted_ticker: AGRI-U.TO
#
# Processing row 17...
# Search results for 'Aimia Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/AIM.TO/']
# extracted_ticker: AIM.TO
#
# Processing row 18...
# Search results for 'Air Canada site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/AC.TO/']
# extracted_ticker: AC.TO
#
# Processing row 19...
# Search results for 'AirBoss of America Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BOS.TO/']
# extracted_ticker: BOS.TO
#
# Processing row 20...
# Search results for 'Akita Drilling Ltd- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/AKT-A.TO/']
# extracted_ticker: AKT-A.TO
#
# Processing row 21...
# Search results for 'Akumin Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/AKU.TO/']
# extracted_ticker: AKU.TO
#
# Processing row 22...
# Search results for 'Alamos Gold Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/AGI.TO/']
# extracted_ticker: AGI.TO
#
# Processing row 23...
# Search results for 'Algoma Central Corporation site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ALC.TO/']
# extracted_ticker: ALC.TO
#
# Processing row 24...
# Search results for 'Algoma Steel Group Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ASTL.TO/']
# extracted_ticker: ASTL.TO
#
# Processing row 25...
# Search results for 'Algonquin Power & Utilities Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/AQN.TO/']
# extracted_ticker: AQN.TO
#
# Processing row 26...
# Search results for 'Alimentation Couche-Tard Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ATD.TO/']
# extracted_ticker: ATD.TO
#
# Processing row 27...
# Search results for 'Alithya Group inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ALYA.TO/']
# extracted_ticker: ALYA.TO
#
# Processing row 28...
# Search results for 'Allied Gold Corporation site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/AAUC.TO/']
# extracted_ticker: AAUC.TO
#
# Processing row 29...
# Search results for 'Almaden Minerals Ltd- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/AMM.TO/']
# extracted_ticker: AMM.TO
#
# Processing row 30...
# Search results for 'Almonty Industries Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/AII.TO/']
# extracted_ticker: AII.TO
#
# Processing row 31...
# Search results for 'Alta Copper Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ATCU.TO?p=ATCU.TO']
# extracted_ticker: ATCU.TO
#
# Processing row 32...
# Search results for 'AltaGas Ltd- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ALA.TO/']
# extracted_ticker: ALA.TO
#
# Processing row 33...
# Search results for 'Altius Minerals Corporation site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ALS.TO/']
# extracted_ticker: ALS.TO
#
# Processing row 34...
# Search results for 'Altius Renewable Royalties Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ARR.TO/']
# extracted_ticker: ARR.TO
#
# Processing row 35...
# Search results for 'Altus Group Limited site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/AIF.TO/']
# extracted_ticker: AIF.TO
#
# Processing row 36...
# Search results for 'American Hotel Income Properties REIT LP site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/HOT-UN.TO/']
# extracted_ticker: HOT-UN.TO
#
# Processing row 37...
# Search results for 'Americas Gold and Silver Corporation site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/USA.TO/']
# extracted_ticker: USA.TO
#
# Processing row 38...
# Search results for 'Amerigo Resources Ltd- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ARG.TO/']
# extracted_ticker: ARG.TO
#
# Processing row 39...
# Search results for 'Anaergia Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ANRG.TO/']
# extracted_ticker: ANRG.TO
#
# Processing row 40...
# Search results for 'Andlauer Healthcare Group Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/and.to/']
# extracted_ticker: and.to
#
# Processing row 41...
# Search results for 'Andrew Peller Limited/Andrew Peller Limitee site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ADW-A.TO/financials/']
# extracted_ticker: ADW-A.TO
#
# Processing row 42...
# Search results for 'Antibe Therapeutics Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ATE.TO/']
# extracted_ticker: ATE.TO
#
# Processing row 43...
# Search results for 'Appili Therapeutics Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/APLI.TO/']
# extracted_ticker: APLI.TO
#
# Processing row 44...
# Search results for 'Aptose Biosciences Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/APS.TO/']
# extracted_ticker: APS.TO
#
# Processing row 45...
# Search results for 'ARC Resources Ltd- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ARX.TO/']
# extracted_ticker: ARX.TO
#
# Processing row 46...
# Search results for 'Argonaut Gold Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/AR.TO/']
# extracted_ticker: AR.TO
#
# Processing row 47...
# Search results for 'Aris Mining Corporation site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ARIS.TO/']
# extracted_ticker: ARIS.TO
#
# Processing row 48...
# Search results for 'Aritzia Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ATZ.TO/']
# extracted_ticker: ATZ.TO
#
# Processing row 49...
# Search results for 'Arizona Metals Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/AMC.TO/']
# extracted_ticker: AMC.TO
#
# Processing row 50...
# Search results for 'Arizona Sonoran Copper Company Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ASCU.TO/']
# extracted_ticker: ASCU.TO
#
# Processing row 51...
# Search results for 'Arrow Long/Short Alternative Class site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote?p=ACAA.TO']
# extracted_ticker: None
#
# Processing row 52...
# Search results for 'Ascendant Resources Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ASND.TO/']
# extracted_ticker: ASND.TO
#
# Processing row 53...
# Search results for 'Ascot Resources Ltd- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/AOT.TO/']
# extracted_ticker: AOT.TO
#
# Processing row 54...
# Search results for 'ATCO Ltd- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ACO-X.TO/']
# extracted_ticker: ACO-X.TO
#
# Processing row 55...
# Search results for 'Athabasca Oil Corporation site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ATH.TO/']
# extracted_ticker: ATH.TO
#
# Processing row 56...
# Search results for 'Atrium Mortgage Investment Corporation site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/AI.TO/']
# extracted_ticker: AI.TO
#
# Processing row 57...
# Search results for 'ATS Corporation site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ATS.TO/']
# extracted_ticker: ATS.TO
#
# Processing row 58...
# Search results for 'Augusta Gold Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/G.TO/']
# extracted_ticker: G.TO
#
# Processing row 59...
# Search results for 'Aura Minerals Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ORA.TO/']
# extracted_ticker: ORA.TO
#
# Processing row 60...
# Search results for 'Aurora Cannabis Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ACB.TO/']
# extracted_ticker: ACB.TO
#
# Processing row 61...
# Search results for 'AutoCanada Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ACQ.TO/']
# extracted_ticker: ACQ.TO
#
# Processing row 62...
# Search results for 'Auxly Cannabis Group Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/XLY.TO/']
# extracted_ticker: XLY.TO
#
# Processing row 63...
# Search results for 'Avalon Advanced Materials Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/AVL.TO/']
# extracted_ticker: AVL.TO
#
# Processing row 64...
# Search results for 'Avant Brands Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/AVNT.TO/']
# extracted_ticker: AVNT.TO
#
# Processing row 65...
# Search results for 'Avicanna Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/AVCN.TO/']
# extracted_ticker: AVCN.TO
#
# Processing row 66...
# Search results for 'Avino Silver & Gold Mines Ltd- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ASM.TO/']
# extracted_ticker: ASM.TO
#
# Processing row 67...
# Search results for 'Axis Auto Finance Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/AXIS.TO/']
# extracted_ticker: AXIS.TO
#
# Processing row 68...
# Search results for 'Aya Gold & Silver Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/AYA.TO/']
# extracted_ticker: AYA.TO
#
# Processing row 69...
# Search results for 'Barrick Gold Corporation site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ABX.TO/']
# extracted_ticker: ABX.TO
#
# Processing row 70...
# Search results for 'Golden Minerals Company site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/AUMN.TO/']
# extracted_ticker: AUMN.TO
#
# Processing row 71...
# Search results for 'HealWELL AI Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/AIDX.TO/']
# extracted_ticker: AIDX.TO
#
# Processing row 72...
# Search results for 'SNC-Lavalin Group Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ATRL.TO/']
# extracted_ticker: ATRL.TO
#
# Processing row 73...
# Search results for 'AirBoss of America Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BOS.TO/']
# extracted_ticker: BOS.TO
#
# Processing row 74...
# Search results for 'B2Gold Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BTO.TO/']
# extracted_ticker: BTO.TO
#
# Processing row 75...
# Search results for 'Badger Infrastructure Solutions Ltd- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BDGI.TO/']
# extracted_ticker: BDGI.TO
#
# Processing row 76...
# Search results for 'Ballard Power Systems Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BLDP.TO/']
# extracted_ticker: BLDP.TO
#
# Processing row 77...
# Search results for 'Bank of Montreal site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BMO.TO/']
# extracted_ticker: BMO.TO
#
# Processing row 78...
# Search results for 'Bank of Nova Scotia (The) site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BNS.TO/']
# extracted_ticker: BNS.TO
#
# Processing row 79...
# Search results for 'Barrick Gold Corporation site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ABX.TO/']
# extracted_ticker: ABX.TO
#
# Processing row 80...
# Search results for 'Bausch + Lomb Corporation site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BLCO.TO/']
# extracted_ticker: BLCO.TO
#
# Processing row 81...
# Search results for 'Bausch Health Companies Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BHC.TO/']
# extracted_ticker: BHC.TO
#
# Processing row 82...
# Search results for 'Baylin Technologies Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BYL.TO/']
# extracted_ticker: BYL.TO
#
# Processing row 83...
# Search results for 'Baytex Energy Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BTE.TO/']
# extracted_ticker: BTE.TO
#
# Processing row 84...
# Search results for 'BCE Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BCE.TO/']
# extracted_ticker: BCE.TO
#
# Processing row 85...
# Search results for 'Becker Milk Company Ltd- (The) site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BEK-B.TO/']
# extracted_ticker: BEK-B.TO
#
# Processing row 86...
# Search results for 'Belo Sun Mining Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BSX.TO/']
# extracted_ticker: BSX.TO
#
# Processing row 87...
# Search results for 'Bengal Energy Ltd- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BNG.TO/']
# extracted_ticker: BNG.TO
#
# Processing row 88...
# Search results for 'Big Banc Split Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BNK.TO/']
# extracted_ticker: BNK.TO
#
# Processing row 89...
# Search results for 'Big Pharma Split Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/PRM.TO/']
# extracted_ticker: PRM.TO
#
# Processing row 90...
# Search results for 'Big Rock Brewery Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BR.TO/']
# extracted_ticker: BR.TO
#
# Processing row 91...
# Search results for 'BIP Investment Corporation site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BIK-PA.TO?p=BIK-PA.TO&ncid=yahooproperties_stockrecom_g40boan2td8']
# extracted_ticker: BIK-PA.TO
#
# Processing row 92...
# Search results for 'Birchcliff Energy Ltd- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BIR.TO?p=BIR.TO']
# extracted_ticker: BIR.TO
#
# Processing row 93...
# Search results for 'Bird Construction Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BDT.TO/']
# extracted_ticker: BDT.TO
#
# Processing row 94...
# Search results for 'Bitfarms Ltd- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BITF.TO/']
# extracted_ticker: BITF.TO
#
# Processing row 95...
# Search results for 'Black Diamond Group Limited site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BDI.TO/']
# extracted_ticker: BDI.TO
#
# Processing row 96...
# Search results for 'Black Iron Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BKI.TO/']
# extracted_ticker: BKI.TO
#
# Processing row 97...
# Search results for 'BlackBerry Limited site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BB.TO/']
# extracted_ticker: BB.TO
#
# Processing row 98...
# Search results for 'Blackline Safety Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BLN.TO/']
# extracted_ticker: BLN.TO
#
# Processing row 99...
# Search results for 'BMTC Group Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/GBT.TO/']
# extracted_ticker: GBT.TO
#
# Processing row 100...
# Search results for 'Boat Rocker Media Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BRMI.TO/']
# extracted_ticker: BRMI.TO
#
# Processing row 101...
# Search results for 'Bombardier Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BBD-B.TO/']
# extracted_ticker: BBD-B.TO
#
# Processing row 102...
# Search results for 'Bonterra Energy Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BNE.TO/']
# extracted_ticker: BNE.TO
#
# Processing row 103...
# Search results for 'Boralex Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BLX.TO/']
# extracted_ticker: BLX.TO
#
# Processing row 104...
# Search results for 'Boyd Group Services Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BYD.TO/profile/']
# extracted_ticker: BYD.TO
#
# Processing row 105...
# Search results for 'Bragg Gaming Group Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BRAG.TO/']
# extracted_ticker: BRAG.TO
#
# Processing row 106...
# Search results for 'Bri-Chem Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BRY.TO/']
# extracted_ticker: BRY.TO
#
# Processing row 107...
# Search results for 'BriaCell Therapeutics Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BCT.TO/']
# extracted_ticker: BCT.TO
#
# Processing row 108...
# Search results for 'Bridgemarq Real Estate Services Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BRE.TO/']
# extracted_ticker: BRE.TO
#
# Processing row 109...
# Search results for 'Brompton Energy Split Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ESP.TO/']
# extracted_ticker: ESP.TO
#
# Processing row 110...
# Search results for 'Brompton Lifeco Split Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/LCS.TO/']
# extracted_ticker: LCS.TO
#
# Processing row 111...
# Search results for 'Brompton Split Banc Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/SBC.TO/']
# extracted_ticker: SBC.TO
#
# Processing row 112...
# Search results for 'Brookfield Asset Management Ltd- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BAM.TO/']
# extracted_ticker: BAM.TO
#
# Processing row 113...
# Search results for 'Brookfield Business Corporation site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BBUC.TO/']
# extracted_ticker: BBUC.TO
#
# Processing row 114...
# Search results for 'Brookfield Business Partners L-P- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BBU-UN.TO/']
# extracted_ticker: BBU-UN.TO
#
# Processing row 115...
# Search results for 'Brookfield Corporation site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BN.TO/']
# extracted_ticker: BN.TO
#
# Processing row 116...
# Search results for 'Brookfield Infrastructure Corporation site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BIPC.TO/']
# extracted_ticker: BIPC.TO
#
# Processing row 117...
# Search results for 'Brookfield Infrastructure Partners L-P- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BIP-UN.TO/']
# extracted_ticker: BIP-UN.TO
#
# Processing row 118...
# Search results for 'Brookfield Office Properties Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BPO-PX.TO/']
# extracted_ticker: BPO-PX.TO
#
# Processing row 119...
# Search results for 'Brookfield Property Preferred L-P- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BPYP-PA.TO/']
# extracted_ticker: BPYP-PA.TO
#
# Processing row 120...
# Search results for 'Brookfield Property Split Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BPYPP/key-statistics/']
# extracted_ticker: BPYPP
#
# Processing row 121...
# Search results for 'Brookfield Reinsurance Ltd- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BNRE/']
# extracted_ticker: BNRE
#
# Processing row 122...
# Search results for 'Brookfield Renewable Corporation site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BEPC.TO/']
# extracted_ticker: BEPC.TO
#
# Processing row 123...
# Search results for 'Brookfield Renewable Partners L-P- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BEP-UN.TO/']
# extracted_ticker: BEP-UN.TO
#
# Processing row 124...
# Search results for 'Brookfield Renewable Power Preferred Equity Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BRF-PA.TO/']
# extracted_ticker: BRF-PA.TO
#
# Processing row 125...
# Search results for 'BRP Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/DOO.TO/']
# extracted_ticker: DOO.TO
#
# Processing row 126...
# Search results for 'Buhler Industries Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BUI.TO/']
# extracted_ticker: BUI.TO
#
# Processing row 127...
# Search results for 'Burcon Nutrascience Corporation site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BU.TO/']
# extracted_ticker: BU.TO
#
# Processing row 128...
# Search results for 'Canadian Banc Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BK.TO/']
# extracted_ticker: BK.TO
#
# Processing row 129...
# Search results for 'Else Nutrition Holdings Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BABY.TO/']
# extracted_ticker: BABY.TO
#
# Processing row 130...
# Search results for 'CAE Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CAE.TO/']
# extracted_ticker: CAE.TO
#
# Processing row 131...
# Search results for 'Caldwell Partners International Inc- (The) site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CWL.TO/']
# extracted_ticker: CWL.TO
#
# Processing row 132...
# Search results for 'Calfrac Well Services Ltd- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CFW.TO/']
# extracted_ticker: CFW.TO
#
# Processing row 133...
# Search results for 'Calian Group Ltd- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/cgy.to/']
# extracted_ticker: cgy.to
#
# Processing row 134...
# Search results for 'Calibre Mining Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CXB.TO/']
# extracted_ticker: CXB.TO
#
# Processing row 135...
# Search results for 'Cameco Corporation site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CCO.TO/']
# extracted_ticker: CCO.TO
#
# Processing row 136...
# Search results for 'Canaccord Genuity Group Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CF.TO/']
# extracted_ticker: CF.TO
#
# Processing row 137...
# Search results for 'Canacol Energy Ltd- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CNE.TO/']
# extracted_ticker: CNE.TO
#
# Processing row 138...
# Search results for 'Canada Goose Holdings Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/GOOS.TO/']
# extracted_ticker: GOOS.TO
#
# Processing row 139...
# Search results for 'Canadian Banc Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BK.TO/']
# extracted_ticker: BK.TO
#
# Processing row 140...
# Search results for 'Canadian General Investments, Limited site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CGI.TO/']
# extracted_ticker: CGI.TO
#
# Processing row 141...
# Search results for 'Canadian Imperial Bank Of Commerce site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CM.TO/']
# extracted_ticker: CM.TO
#
# Processing row 142...
# Search results for 'Canadian Life Companies Split Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/LFE.TO/']
# extracted_ticker: LFE.TO
#
# Processing row 143...
# Search results for 'Canadian National Railway Company site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CNR.TO/']
# extracted_ticker: CNR.TO
#
# Processing row 144...
# Search results for 'Canadian Natural Resources Limited site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CNQ.TO/']
# extracted_ticker: CNQ.TO
#
# Processing row 145...
# Search results for 'Canadian Pacific Kansas City Limited site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CP.TO/']
# extracted_ticker: CP.TO
#
# Processing row 146...
# Search results for 'Canadian Tire Corporation, Limited site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CTC-A.TO/']
# extracted_ticker: CTC-A.TO
#
# Processing row 147...
# Search results for 'Canadian Utilities Limited site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CU.TO/']
# extracted_ticker: CU.TO
#
# Processing row 148...
# Search results for 'Canadian Western Bank site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CWB.TO/']
# extracted_ticker: CWB.TO
#
# Processing row 149...
# Search results for 'Canagold Resources Ltd- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CCM.TO/']
# extracted_ticker: CCM.TO
#
# Processing row 150...
# Search results for 'Canfor Corporation site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CFP.TO/']
# extracted_ticker: CFP.TO
#
# Processing row 151...
# Search results for 'Canfor Pulp Products Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CFX.TO/']
# extracted_ticker: CFX.TO
#
# Processing row 152...
# Search results for 'Canlan Ice Sports Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ICE.TO/profile/']
# extracted_ticker: ICE.TO
#
# Processing row 153...
# Search results for 'Canopy Growth Corporation site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/WEED.TO/']
# extracted_ticker: WEED.TO
#
# Processing row 154...
# Search results for 'Capital Power Corporation site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CPX.TO/']
# extracted_ticker: CPX.TO
#
# Processing row 155...
# Search results for 'Capstone Copper Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CS.TO/']
# extracted_ticker: CS.TO
#
# Processing row 156...
# Search results for 'Capstone Infrastructure Corporation site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/cse-pa.to/']
# extracted_ticker: cse-pa.to
#
# Processing row 157...
# Search results for 'Cardinal Energy Ltd- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CJ.TO/']
# extracted_ticker: CJ.TO
#
# Processing row 158...
# Search results for 'Cardiol Therapeutics Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CRDL.TO/']
# extracted_ticker: CRDL.TO
#
# Processing row 159...
# Search results for 'CareRx Corporation site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CRRX.TO/']
# extracted_ticker: CRRX.TO
#
# Processing row 160...
# Search results for 'Cargojet Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CJT.TO/']
# extracted_ticker: CJT.TO
#
# Processing row 161...
# Search results for 'Caribbean Utilities Company, Ltd- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CUP-U.TO/']
# extracted_ticker: CUP-U.TO
#
# Processing row 162...
# Search results for 'Cascades Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CAS.TO/']
# extracted_ticker: CAS.TO
#
# Processing row 163...
# Search results for 'Cathedral Energy Services Ltd- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CET.TO/']
# extracted_ticker: CET.TO
#
# Processing row 164...
# Search results for 'CCL Industries Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CCL-B.TO/']
# extracted_ticker: CCL-B.TO
#
# Processing row 165...
# Search results for 'Celestica Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CLS.TO/']
# extracted_ticker: CLS.TO
#
# Processing row 166...
# Search results for 'Cenovus Energy Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CVE.TO/']
# extracted_ticker: CVE.TO
#
# Processing row 167...
# Search results for 'Centamin plc site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/cee.to/']
# extracted_ticker: cee.to
#
# Processing row 168...
# Search results for 'Centerra Gold Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CG.TO/']
# extracted_ticker: CG.TO
#
# Processing row 169...
# Search results for 'Century Global Commodities Corporation site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CNT.TO/']
# extracted_ticker: CNT.TO
#
# Processing row 170...
# Search results for 'Ceres Global Ag Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CRP.TO/']
# extracted_ticker: CRP.TO
#
# Processing row 171...
# Search results for 'Ceridian HCM Holding Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CDAY.TO/']
# extracted_ticker: CDAY.TO
#
# Processing row 172...
# Search results for 'CES Energy Solutions Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CEU.TO/']
# extracted_ticker: CEU.TO
#
# Processing row 173...
# Search results for 'CGI Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/GIB-A.TO/']
# extracted_ticker: GIB-A.TO
#
# Processing row 174...
# Search results for 'Champion Iron Limited site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CIA.TO/']
# extracted_ticker: CIA.TO
#
# Processing row 175...
# Search results for 'Charlotte's Web Holdings, Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CWEB.TO/']
# extracted_ticker: CWEB.TO
#
# Processing row 176...
# Search results for 'Chartwell Retirement Residences site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CSH-UN.TO/']
# extracted_ticker: CSH-UN.TO
#
# Processing row 177...
# Search results for 'Chesswood Group Limited site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CHW.TO/']
# extracted_ticker: CHW.TO
#
# Processing row 178...
# Search results for 'China Gold International Resources Corp- Ltd- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CGG.TO/']
# extracted_ticker: CGG.TO
#
# Processing row 179...
# Search results for 'Chorus Aviation Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/chr.to/']
# extracted_ticker: chr.to
#
# Processing row 180...
# Search results for 'CI Financial Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CIX.TO/']
# extracted_ticker: CIX.TO
#
# Processing row 181...
# Search results for 'CI Global Asset Allocation Private Pool site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CGAA.TO/holdings/']
# extracted_ticker: CGAA.TO
#
# Processing row 182...
# Search results for 'CI Global High Yield Credit Private Pool site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CGHY.TO']
# extracted_ticker: CGHY.TO
#
# Processing row 183...
# Search results for 'CI Global Infrastructure Private Pool site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CINF.TO/holdings/']
# extracted_ticker: CINF.TO
#
# Processing row 184...
# Search results for 'CI Global Real Asset Private Pool site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CGRA.TO/']
# extracted_ticker: CGRA.TO
#
# Processing row 185...
# Search results for 'CI Global REIT Private Pool site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CGRE.TO/holdings/']
# extracted_ticker: CGRE.TO
#
# Processing row 186...
# Search results for 'CIBC Conservative Fixed Income Pool site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/0P0001IMXJ.TO/']
# extracted_ticker: 0P0001IMXJ.TO
#
# Processing row 187...
# Search results for 'CIBC Core Fixed Income Pool site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CCRE.TO/']
# extracted_ticker: CCRE.TO
#
# Processing row 188...
# Search results for 'CIBC Core Plus Fixed Income Pool site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/0P0001IMXR.TO/']
# extracted_ticker: 0P0001IMXR.TO
#
# Processing row 189...
# Search results for 'Cineplex Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CGX.TO/']
# extracted_ticker: CGX.TO
#
# Processing row 190...
# Search results for 'Cipher Pharmaceuticals Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CPH.TO/']
# extracted_ticker: CPH.TO
#
# Processing row 191...
# Search results for 'Clairvest Group Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CVG.TO/']
# extracted_ticker: CVG.TO
#
# Processing row 192...
# Search results for 'Clarke Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CKI.TO/']
# extracted_ticker: CKI.TO
#
# Processing row 193...
# Search results for 'Co-operators General Insurance Company site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CCS-PC.TO/']
# extracted_ticker: CCS-PC.TO
#
# Processing row 194...
# Search results for 'Cogeco Communications Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CCA.TO/']
# extracted_ticker: CCA.TO
#
# Processing row 195...
# Search results for 'Cogeco Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CCA.TO/']
# extracted_ticker: CCA.TO
#
# Processing row 196...
# Search results for 'Colabor Group Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/GCL.TO/']
# extracted_ticker: GCL.TO
#
# Processing row 197...
# Search results for 'Collective Mining Ltd- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/cnl.to/']
# extracted_ticker: cnl.to
#
# Processing row 198...
# Search results for 'Colliers International Group Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CIGI.TO/']
# extracted_ticker: CIGI.TO
#
# Processing row 199...
# Search results for 'Commerce Split Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/YCM-PA.TO/']
# extracted_ticker: YCM-PA.TO
#
# Processing row 200...
# Search results for 'Computer Modelling Group Ltd- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CMG.TO/']
# extracted_ticker: CMG.TO
#
# Processing row 201...
# Search results for 'Condor Energies Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CDR.TO/']
# extracted_ticker: CDR.TO
#
# Processing row 202...
# Search results for 'Condor Gold plc site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/COG.TO/']
# extracted_ticker: COG.TO
#
# Processing row 203...
# Search results for 'Conifex Timber Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CFF.TO/']
# extracted_ticker: CFF.TO
#
# Processing row 204...
# Search results for 'Constellation Software Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CSU.TO/']
# extracted_ticker: CSU.TO
#
# Processing row 205...
# Search results for 'Converge Technology Solutions Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CTS.TO/']
# extracted_ticker: CTS.TO
#
# Processing row 206...
# Search results for 'Copperleaf Technologies Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CPLF.TO/']
# extracted_ticker: CPLF.TO
#
# Processing row 207...
# Search results for 'Corby Spirit and Wine Limited site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/csw-a.to/']
# extracted_ticker: csw-a.to
#
# Processing row 208...
# Search results for 'Corus Entertainment Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CJR-B.TO/']
# extracted_ticker: CJR-B.TO
#
# Processing row 209...
# Search results for 'Coveo Solutions Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CVO.TO/']
# extracted_ticker: CVO.TO
#
# Processing row 210...
# Search results for 'Crescent Point Energy Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CPG.TO/']
# extracted_ticker: CPG.TO
#
# Processing row 211...
# Search results for 'Crescita Therapeutics Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CTX.TO/']
# extracted_ticker: CTX.TO
#
# Processing row 212...
# Search results for 'Crew Energy Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CR.TO/']
# extracted_ticker: CR.TO
#
# Processing row 213...
# Search results for 'Cronos Group Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CRON.TO/']
# extracted_ticker: CRON.TO
#
# Processing row 214...
# Search results for 'Crown Capital Partners Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CRWN.TO/']
# extracted_ticker: CRWN.TO
#
# Processing row 215...
# Search results for 'CU Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ciu-pc.to/']
# extracted_ticker: ciu-pc.to
#
# Processing row 216...
# Search results for 'Curaleaf Holdings, Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CURA.TO/']
# extracted_ticker: CURA.TO
#
# Processing row 217...
# Search results for 'Currency Exchange International, Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CXI.TO/']
# extracted_ticker: CXI.TO
#
# Processing row 218...
# Search results for 'Cymbria Corporation site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/CYB.TO/']
# extracted_ticker: CYB.TO
#
# Processing row 219...
# Search results for 'ADF Group Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/DRX.TO/']
# extracted_ticker: DRX.TO
#
# Processing row 220...
# Search results for 'BRP Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/DOO.TO/']
# extracted_ticker: DOO.TO
#
# Processing row 221...
# Search results for 'D-Box Technologies Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/DBO.TO/']
# extracted_ticker: DBO.TO
#
# Processing row 222...
# Search results for 'D2L Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/DTOL.TO/']
# extracted_ticker: DTOL.TO
#
# Processing row 223...
# Search results for 'Data Communications Management Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/DCM.TO/']
# extracted_ticker: DCM.TO
#
# Processing row 224...
# Search results for 'Definity Financial Corporation site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/DFY.TO/']
# extracted_ticker: DFY.TO
#
# Processing row 225...
# Search results for 'Delta 9 Cannabis Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/DN.TO/']
# extracted_ticker: DN.TO
#
# Processing row 226...
# Search results for 'Denison Mines Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/DML.TO/']
# extracted_ticker: DML.TO
#
# Processing row 227...
# Search results for 'dentalcorp Holdings Ltd- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/DNTL.TO/']
# extracted_ticker: DNTL.TO
#
# Processing row 228...
# Search results for 'Descartes Systems Group Inc- (The) site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/DSG.TO/']
# extracted_ticker: DSG.TO
#
# Processing row 229...
# Search results for 'Dexterra Group Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/DXT.TO/']
# extracted_ticker: DXT.TO
#
# Processing row 230...
# Search results for 'DIRTT Environmental Solutions Ltd- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/DRT.TO/']
# extracted_ticker: DRT.TO
#
# Processing row 231...
# Search results for 'Discovery Silver Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/DSV.TO/']
# extracted_ticker: DSV.TO
#
# Processing row 232...
# Search results for 'Diversified Royalty Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/DIV.TO/']
# extracted_ticker: DIV.TO
#
# Processing row 233...
# Search results for 'Dividend 15 Split Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/DFN.TO/']
# extracted_ticker: DFN.TO
#
# Processing row 234...
# Search results for 'Dividend 15 Split Corp- II site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/DF.TO/']
# extracted_ticker: DF.TO
#
# Processing row 235...
# Search results for 'Dividend Growth Split Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/DGS.TO/']
# extracted_ticker: DGS.TO
#
# Processing row 236...
# Search results for 'Dividend Select 15 Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/DS.TO/']
# extracted_ticker: DS.TO
#
# Processing row 237...
# Search results for 'Docebo Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/DCBO.TO/']
# extracted_ticker: DCBO.TO
#
# Processing row 238...
# Search results for 'Dollarama Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/dol.to/']
# extracted_ticker: dol.to
#
# Processing row 239...
# Search results for 'Doman Building Materials Group Ltd- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/DBM.TO/']
# extracted_ticker: DBM.TO
#
# Processing row 240...
# Search results for 'Dominion Lending Centres Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/DLCG.TO/']
# extracted_ticker: DLCG.TO
#
# Processing row 241...
# Search results for 'Dorel Industries Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/DII-B.TO/']
# extracted_ticker: DII-B.TO
#
# Processing row 242...
# Search results for 'DREAM Unlimited Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/DRM.TO/']
# extracted_ticker: DRM.TO
#
# Processing row 243...
# Search results for 'Dundee Corporation site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/DC-A.TO/']
# extracted_ticker: DC-A.TO
#
# Processing row 244...
# Search results for 'Dundee Precious Metals Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/DPM.TO/']
# extracted_ticker: DPM.TO
#
# Processing row 245...
# Search results for 'Dye & Durham Limited site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/DND.TO/']
# extracted_ticker: DND.TO
#
# Processing row 246...
# Search results for 'dynaCERT Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/DYA.TO/']
# extracted_ticker: DYA.TO
#
# Processing row 247...
# Search results for 'Dynacor Group Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/DNG.TO/']
# extracted_ticker: DNG.TO
#
# Processing row 248...
# Search results for 'Medical Facilities Corporation site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/DR.TO/']
# extracted_ticker: DR.TO
#
# Processing row 249...
# Search results for 'Star Diamond Corporation site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/DIAM.TO/']
# extracted_ticker: DIAM.TO
#
# Processing row 250...
# Search results for 'Brompton Energy Split Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ESP.TO/']
# extracted_ticker: ESP.TO
#
# Processing row 251...
# Search results for 'E Split Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ENS.TO/']
# extracted_ticker: ENS.TO
#
# Processing row 252...
# Search results for 'E-L Financial Corporation Limited site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ELF.TO/']
# extracted_ticker: ELF.TO
#
# Processing row 253...
# Search results for 'East Side Games Group Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/EAGR.TO/']
# extracted_ticker: EAGR.TO
#
# Processing row 254...
# Search results for 'Eastern Platinum Limited site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ELR.TO/']
# extracted_ticker: ELR.TO
#
# Processing row 255...
# Search results for 'ECN Capital Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ECN.TO/']
# extracted_ticker: ECN.TO
#
# Processing row 256...
# Search results for 'Ecora Resources plc site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ECRAF/']
# extracted_ticker: ECRAF
#
# Processing row 257...
# Search results for 'EcoSynthetix Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ECO.TO/']
# extracted_ticker: ECO.TO
#
# Processing row 258...
# Search results for 'Eldorado Gold Corporation site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/eld.to/']
# extracted_ticker: eld.to
#
# Processing row 259...
# Search results for 'Electrovaya Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ELVA.TO/']
# extracted_ticker: ELVA.TO
#
# Processing row 260...
# Search results for 'Element Fleet Management Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/EFN.TO/']
# extracted_ticker: EFN.TO
#
# Processing row 261...
# Search results for 'Eloro Resources Ltd- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ELO.TO/']
# extracted_ticker: ELO.TO
#
# Processing row 262...
# Search results for 'Else Nutrition Holdings Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/BABY.TO/']
# extracted_ticker: BABY.TO
#
# Processing row 263...
# Search results for 'Emera Incorporated site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/EMA.TO/']
# extracted_ticker: EMA.TO
#
# Processing row 264...
# Search results for 'Empire Company Limited site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/EMP-A.TO/']
# extracted_ticker: EMP-A.TO
#
# Processing row 265...
# Search results for 'Enbridge Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ENB.TO/']
# extracted_ticker: ENB.TO
#
# Processing row 266...
# Search results for 'Endeavour Mining plc site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/EDV.TO/']
# extracted_ticker: EDV.TO
#
# Processing row 267...
# Search results for 'Endeavour Silver Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/EDR.TO/']
# extracted_ticker: EDR.TO
#
# Processing row 268...
# Search results for 'Enerflex Ltd- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/EFX.TO/']
# extracted_ticker: EFX.TO
#
# Processing row 269...
# Search results for 'Energy Fuels Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/efr.to/']
# extracted_ticker: efr.to
#
# Processing row 270...
# Search results for 'Enerplus Corporation site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ERF.TO/']
# extracted_ticker: ERF.TO
#
# Processing row 271...
# Search results for 'Enghouse Systems Limited site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ENGH.TO/']
# extracted_ticker: ENGH.TO
#
# Processing row 272...
# Search results for 'Ensign Energy Services Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ESI.TO/']
# extracted_ticker: ESI.TO
#
# Processing row 273...
# Search results for 'Enterprise Group, Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/e.to/']
# extracted_ticker: e.to
#
# Processing row 274...
# Search results for 'Enthusiast Gaming Holdings Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/EGLX.TO/']
# extracted_ticker: EGLX.TO
#
# Processing row 275...
# Search results for 'Entree Resources Ltd- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ETG.TO/']
# extracted_ticker: ETG.TO
#
# Processing row 276...
# ...
# extracted_ticker: TPZ.TO
#
# Processing row 737...
# Search results for 'Torex Gold Resources Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/TXG.TO/']
# extracted_ticker: TXG.TO
#
# Processing row 738...
# Search results for 'Toromont Industries Ltd- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/tih.to/']
# extracted_ticker: tih.to
#
# Processing row 739...
# Search results for 'Toronto-Dominion Bank (The) site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/TD.TO/']
# extracted_ticker: TD.TO
#
# Processing row 740...
# Search results for 'Total Energy Services Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/TOT.TO/']
# extracted_ticker: TOT.TO
#
# Processing row 741...
# Search results for 'Touchstone Exploration Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/TXP.TO/']
# extracted_ticker: TXP.TO
#
# Processing row 742...
# Search results for 'Tourmaline Oil Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/tou.to/']
# extracted_ticker: tou.to
#
# Processing row 743...
# Search results for 'TransAlta Corporation site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/TA.TO/']
# extracted_ticker: TA.TO
#
# Processing row 744...
# Search results for 'Transat A-T- Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/TRZ.TO/']
# extracted_ticker: TRZ.TO
#
# Processing row 745...
# Search results for 'Transcontinental Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/TCL-A.TO/']
# extracted_ticker: TCL-A.TO
#
# Processing row 746...
# Search results for 'Treasury Metals Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/TML.TO/']
# extracted_ticker: TML.TO
#
# Processing row 747...
# Search results for 'Tree Island Steel Ltd- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/TSL.TO/']
# extracted_ticker: TSL.TO
#
# Processing row 748...
# Search results for 'Trican Well Service Ltd- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/TCW.TO/']
# extracted_ticker: TCW.TO
#
# Processing row 749...
# Search results for 'Tricon Residential Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/TCN.TO/']
# extracted_ticker: TCN.TO
#
# Processing row 750...
# Search results for 'Trilogy Metals Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/TMQ.TO/']
# extracted_ticker: TMQ.TO
#
# Processing row 751...
# Search results for 'Triple Flag Precious Metals Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/TFPM.TO/']
# extracted_ticker: TFPM.TO
#
# Processing row 752...
# Search results for 'Trisura Group Ltd- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/TSU.TO/']
# extracted_ticker: TSU.TO
#
# Processing row 753...
# Search results for 'Troilus Gold Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/TLG.TO/']
# extracted_ticker: TLG.TO
#
# Processing row 754...
# Search results for 'TRX Gold Corporation site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/TRX/']
# extracted_ticker: TRX
#
# Processing row 755...
# Search results for 'Tucows Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/TC.TO/']
# extracted_ticker: TC.TO
#
# Processing row 756...
# Search results for 'TVA Group Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/TVA-B.TO/']
# extracted_ticker: TVA-B.TO
#
# Processing row 757...
# Search results for 'TWC Enterprises Limited site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/TWC.TO/']
# extracted_ticker: TWC.TO
#
# Processing row 758...
# Search results for 'Americas Gold and Silver Corporation site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/USA.TO/']
# extracted_ticker: USA.TO
#
# Processing row 759...
# Search results for 'Unisync Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/UNI.TO/']
# extracted_ticker: UNI.TO
#
# Processing row 760...
# Search results for 'United Corporations Limited site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/UNC.TO/']
# extracted_ticker: UNC.TO
#
# Processing row 761...
# Search results for 'Ur-Energy Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ure.to/']
# extracted_ticker: ure.to
#
# Processing row 762...
# Search results for 'Uranium Royalty Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/URC.TO/']
# extracted_ticker: URC.TO
#
# Processing row 763...
# Search results for 'Urbana Corporation site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/URB.TO/']
# extracted_ticker: URB.TO
#
# Processing row 764...
# Search results for 'US Financial 15 Split Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ftu.to/']
# extracted_ticker: ftu.to
#
# Processing row 765...
# Search results for '5N Plus Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/VNP.TO/']
# extracted_ticker: VNP.TO
#
# Processing row 766...
# Search results for 'Gamelancer Media Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/GAMGF/']
# extracted_ticker: GAMGF
#
# Processing row 767...
# Search results for 'Valeo Pharma Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/VPH.TO/']
# extracted_ticker: VPH.TO
#
# Processing row 768...
# Search results for 'Valeura Energy Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/VLE.TO/']
# extracted_ticker: VLE.TO
#
# Processing row 769...
# Search results for 'Vecima Networks Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/VCM.TO/']
# extracted_ticker: VCM.TO
#
# Processing row 770...
# Search results for 'Velan Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/VLN.TO/']
# extracted_ticker: VLN.TO
#
# Processing row 771...
# Search results for 'Verde Agritech Ltd- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/NPK.TO/']
# extracted_ticker: NPK.TO
#
# Processing row 772...
# Search results for 'Vermilion Energy Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/VET.TO/']
# extracted_ticker: VET.TO
#
# Processing row 773...
# Search results for 'VersaBank site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/VBNK.TO/']
# extracted_ticker: VBNK.TO
#
# Processing row 774...
# Search results for 'VerticalScope Holdings Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/FORA.TO/']
# extracted_ticker: FORA.TO
#
# Processing row 775...
# Search results for 'Victoria Gold Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/VGCX.TO/']
# extracted_ticker: VGCX.TO
#
# Processing row 776...
# Search results for 'VIQ Solutions Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/VQS.TO/']
# extracted_ticker: VQS.TO
#
# Processing row 777...
# Search results for 'Vista Gold Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/VGZ.TO/']
# extracted_ticker: VGZ.TO
#
# Processing row 778...
# Search results for 'Vitalhub Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/VHI.TO/']
# extracted_ticker: VHI.TO
#
# Processing row 779...
# Search results for 'VM Hotel Acquisition Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/VMH-U.TO/']
# extracted_ticker: VMH-U.TO
#
# Processing row 780...
# Search results for 'Vox Royalty Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/VOXR/']
# extracted_ticker: VOXR
#
# Processing row 781...
# Search results for 'Canopy Growth Corporation site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/WEED.TO/']
# extracted_ticker: WEED.TO
#
# Processing row 782...
# Search results for 'George Weston Limited site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/WN.TO/']
# extracted_ticker: WN.TO
#
# Processing row 783...
# Search results for 'Wajax Corporation site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/WJX.TO/']
# extracted_ticker: WJX.TO
#
# Processing row 784...
# Search results for 'Wall Financial Corporation site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/WFC.TO/']
# extracted_ticker: WFC.TO
#
# Processing row 785...
# Search results for 'Wallbridge Mining Company Limited site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/WM.TO/']
# extracted_ticker: WM.TO
#
# Processing row 786...
# Search results for 'Waste Connections, Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/WCN.TO/']
# extracted_ticker: WCN.TO
#
# Processing row 787...
# Search results for 'WELL Health Technologies Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/WELL.TO/']
# extracted_ticker: WELL.TO
#
# Processing row 788...
# Search results for 'Wesdome Gold Mines Ltd- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/WDO.TO/']
# extracted_ticker: WDO.TO
#
# Processing row 789...
# Search results for 'West Fraser Timber Co- Ltd- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/WFG.TO/']
# extracted_ticker: WFG.TO
#
# Processing row 790...
# Search results for 'Western Copper and Gold Corporation site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/wrn.to/']
# extracted_ticker: wrn.to
#
# Processing row 791...
# Search results for 'Western Energy Services Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/WRG.TO/']
# extracted_ticker: WRG.TO
#
# Processing row 792...
# Search results for 'Western Forest Products Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/WEF.TO/']
# extracted_ticker: WEF.TO
#
# Processing row 793...
# Search results for 'Western Resources Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/WRX.TO/']
# extracted_ticker: WRX.TO
#
# Processing row 794...
# Search results for 'Westport Fuel Systems Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/WPRT.TO/']
# extracted_ticker: WPRT.TO
#
# Processing row 795...
# Search results for 'Westshore Terminals Investment Corporation site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/WTE.TO/']
# extracted_ticker: WTE.TO
#
# Processing row 796...
# Search results for 'Wheaton Precious Metals Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/WPM.TO/']
# extracted_ticker: WPM.TO
#
# Processing row 797...
# Search results for 'Whitecap Resources Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/wcp.to/']
# extracted_ticker: wcp.to
#
# Processing row 798...
# Search results for 'WildBrain Ltd- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/WILD.TO/']
# extracted_ticker: WILD.TO
#
# Processing row 799...
# Search results for 'Willow Biosciences Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/WLLW.TO/']
# extracted_ticker: WLLW.TO
#
# Processing row 800...
# Search results for 'Wilmington Capital Management Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/WCM-B.TO/']
# extracted_ticker: WCM-B.TO
#
# Processing row 801...
# Search results for 'Winpak Ltd- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/WPK.TO/']
# extracted_ticker: WPK.TO
#
# Processing row 802...
# Search results for 'WonderFi Technologies Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/WNDR.TO/']
# extracted_ticker: WNDR.TO
#
# Processing row 803...
# Search results for 'World Financial Split Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/WFS.TO/']
# extracted_ticker: WFS.TO
#
# Processing row 804...
# Search results for 'WSP Global Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/WSP.TO/']
# extracted_ticker: WSP.TO
#
# Processing row 805...
# Search results for 'Auxly Cannabis Group Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/XLY.TO/']
# extracted_ticker: XLY.TO
#
# Processing row 806...
# Search results for 'Exco Technologies Limited site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/XTC.TO/']
# extracted_ticker: XTC.TO
#
# Processing row 807...
# Search results for 'GoldMoney Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/XAU.TO/']
# extracted_ticker: XAU.TO
#
# Processing row 808...
# Search results for 'M Split Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/XMF-A.TO/']
# extracted_ticker: XMF-A.TO
#
# Processing row 809...
# Search results for 'TDb Split Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/XTD.TO/']
# extracted_ticker: XTD.TO
#
# Processing row 810...
# Search results for 'TMX Group Limited site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/X.TO/']
# extracted_ticker: X.TO
#
# Processing row 811...
# Search results for 'Xanadu Mines Ltd- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/XAM.TO/']
# extracted_ticker: XAM.TO
#
# Processing row 812...
# Search results for 'Xtra-Gold Resources Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/XTG.TO/']
# extracted_ticker: XTG.TO
#
# Processing row 813...
# Search results for 'Xtract One Technologies Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/XTRA.TO/']
# extracted_ticker: XTRA.TO
#
# Processing row 814...
# Search results for 'Commerce Split Corp- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/YCM-PA.TO/']
# extracted_ticker: YCM-PA.TO
#
# Processing row 815...
# Search results for 'Yangarra Resources Ltd- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/YGR.TO/']
# extracted_ticker: YGR.TO
#
# Processing row 816...
# Search results for 'Yellow Pages Limited site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/Y.TO/']
# extracted_ticker: Y.TO
#
# Processing row 817...
# Search results for 'Yorbeau Resources Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/YRB.TO/']
# extracted_ticker: YRB.TO
#
# Processing row 818...
# Search results for 'Sleep Country Canada Holdings Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/ZZZ.TO/']
# extracted_ticker: ZZZ.TO
#
# Processing row 819...
# Search results for '5N Plus Inc- site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/VNP.TO/']
# extracted_ticker: VNP.TO
#
# Processing row 820...
# Search results for 'First National Financial Corporation site:ca.finance.yahoo.com/quote': ['https://ca.finance.yahoo.com/quote/FN.TO/']
# extracted_ticker: FN.TO
#
#                                   Company  \
# 0             Aberdeen International Inc-
# 1                    Acadian Timber Corp-
# 2                  Accord Financial Corp-
# 3                   Aclara Resources Inc-
# 4                             Adcore Inc-
# ..                                    ...
# 815                  Yellow Pages Limited
# 816                Yorbeau Resources Inc-
# 817    Sleep Country Canada Holdings Inc-
# 818                          5N Plus Inc-
# 819  First National Financial Corporation
#
#                                         TMX Link Ticker TMX   Ticker
# 0     https://money-tmx-com/en/quote/AAB/company        AAB   AAB.TO
# 1     https://money-tmx-com/en/quote/ADN/company        ADN   ADN.TO
# 2     https://money-tmx-com/en/quote/ACD/company        ACD   ACD.TO
# 3     https://money-tmx-com/en/quote/ARA/company        ARA   ARA.TO
# 4    https://money-tmx-com/en/quote/ADCO/company       ADCO  ADCO.TO
# ..                                           ...        ...      ...
# 815     https://money-tmx-com/en/quote/Y/company          Y     Y.TO
# 816   https://money-tmx-com/en/quote/YRB/company        YRB   YRB.TO
# 817   https://money-tmx-com/en/quote/ZZZ/company        ZZZ   ZZZ.TO
# 818   https://money-tmx-com/en/quote/VNP/company        VNP   VNP.TO
# 819    https://money-tmx-com/en/quote/FN/company         FN    FN.TO
#
# [820 rows x 4 columns]

# %%
# Create a new DataFrame without rows where Ticker is None
new_df = filtered_df[filtered_df['Ticker'].isna()]

# %%
new_df
# Out:
#                                Company  \
# 50  Arrow Long/Short Alternative Class
#
#                                        TMX Link Ticker TMX Ticker
# 50  https://money-tmx-com/en/quote/ACAA/company       ACAA   None

# %%
# Using new_df as the DataFrame containing tickers. There are some american tickers in this dataset that need to be removed.
new_df['Ticker'] = "ACAA.TO"

# %%
merged_df = filtered_df

# Assuming 'Name' column is common between the two dataframes
name_to_ticker_mapping = new_df.set_index('Company')['Ticker'].to_dict()

# Map the Ticker values from new_df_CAD to filtered_df based on the 'Name' column
merged_df['Ticker'] = filtered_df['Company'].map(name_to_ticker_mapping).fillna(filtered_df['Ticker'])

# %%
merged_df
# Out:
#                                   Company  \
# 0             Aberdeen International Inc-
# 1                    Acadian Timber Corp-
# 2                  Accord Financial Corp-
# 3                   Aclara Resources Inc-
# 4                             Adcore Inc-
# ..                                    ...
# 815                  Yellow Pages Limited
# 816                Yorbeau Resources Inc-
# 817    Sleep Country Canada Holdings Inc-
# 818                          5N Plus Inc-
# 819  First National Financial Corporation
#
#                                         TMX Link Ticker TMX   Ticker
# 0     https://money-tmx-com/en/quote/AAB/company        AAB   AAB.TO
# 1     https://money-tmx-com/en/quote/ADN/company        ADN   ADN.TO
# 2     https://money-tmx-com/en/quote/ACD/company        ACD   ACD.TO
# 3     https://money-tmx-com/en/quote/ARA/company        ARA   ARA.TO
# 4    https://money-tmx-com/en/quote/ADCO/company       ADCO  ADCO.TO
# ..                                           ...        ...      ...
# 815     https://money-tmx-com/en/quote/Y/company          Y     Y.TO
# 816   https://money-tmx-com/en/quote/YRB/company        YRB   YRB.TO
# 817   https://money-tmx-com/en/quote/ZZZ/company        ZZZ   ZZZ.TO
# 818   https://money-tmx-com/en/quote/VNP/company        VNP   VNP.TO
# 819    https://money-tmx-com/en/quote/FN/company         FN    FN.TO
#
# [820 rows x 4 columns]

# %%
# Save the shrunk dataset to a new CSV file
merged_df.to_csv('/content/drive/MyDrive/Colab Notebooks/data/TSX_Companies.csv', index=False, sep=',')

# Provide a download link for the file
from google.colab import files
files.download('/content/drive/MyDrive/Colab Notebooks/data/TSX_Companies.csv')

# %% [markdown]
# # Getting yFiance Data

# %%
import pandas as pd
import yfinance as yf

#DATABASE OF ALL TICKERS AND SOME ATTRIBUTES.

# Create an empty DataFrame to store the results
TSX_Data = pd.DataFrame(columns=["Ticker", "Company", "Sector", "Revenue_2022", "Revenue_2021", "Revenue_2020"])

# Iterate through each row in the dataset
for index, row in merged_df.iterrows():
    try:
        print(f"Processing row {index + 1}...")
        # Fetch the company information
        ticker = row['Ticker']
        company = yf.Ticker(ticker)

        company_name = company.info.get('longName')
        print(f"Company: {company_name} Ticker: {ticker}")

        # Get the sector information
        sector = company.get_info()['sector'] if 'sector' in company.get_info() else company.get_info()['legalType']
        print(f"sector: {sector}\n")
        # Get the revenue data
        revenue = None

        if not company.incomestmt.empty and 'Total Revenue' in company.incomestmt.index:
            revenue = company.incomestmt.loc['Total Revenue']
        else:
            revenue = None

        if revenue is not None:
            keys = list(revenue.keys())
            revenue_2022 = revenue.get(keys[0], None) if len(keys) > 0 else None
            revenue_2021 = revenue.get(keys[1], None) if len(keys) > 1 else None
            revenue_2020 = revenue.get(keys[2], None) if len(keys) > 2 else None
        else:
            revenue_2022 = revenue_2021 = revenue_2020 = "N/A"

        # Append the symbol, sector, and EBITDA to the DataFrame
        TSX_Data.loc[len(TSX_Data)] = [ticker, company_name, sector, revenue_2022, revenue_2021, revenue_2020, ]
    except Exception as e:
            # If an error occurs (e.g., ticker not found), append None for the sector and revenue
            TSX_Data.loc[len(TSX_Data)] = [ticker, company_name, None, None, None, None]
            print(f"Error processing row {index + 1}: {e}")
# Out:
# /usr/local/lib/python3.10/dist-packages/yfinance/base.py:48: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _empty_series = pd.Series()
# Processing row 1...
# Company: Aberdeen International Inc. Ticker: AAB.TO
# sector: Financial Services
#
# Processing row 2...
# Company: Acadian Timber Corp. Ticker: ADN.TO
# sector: Basic Materials
#
# Processing row 3...
# Company: Accord Financial Corp. Ticker: ACD.TO
# sector: Financial Services
#
# Processing row 4...
# Company: Aclara Resources Inc. Ticker: ARA.TO
# sector: Basic Materials
#
# Processing row 5...
# Company: Adcore Inc. Ticker: ADCO.TO
# sector: Technology
#
# Processing row 6...
# Company: ADENTRA Inc. Ticker: ADEN.TO
# sector: Industrials
#
# Processing row 7...
# Company: ADF Group Inc. Ticker: DRX.TO
# sector: Industrials
#
# Processing row 8...
# Company: Advantage Energy Ltd. Ticker: AAV.TO
# sector: Energy
#
# Processing row 9...
# Company: Aecon Group Inc. Ticker: ARE.TO
# sector: Industrials
#
# Processing row 10...
# Company: Aegis Brands Inc. Ticker: AEG.TO
# sector: Consumer Cyclical
#
# Processing row 11...
# Company: Aeterna Zentaris Inc. Ticker: AEZS.TO
# sector: Healthcare
#
# Processing row 12...
# Company: Africa Oil Corp. Ticker: AOI.TO
# sector: Energy
#
# Processing row 13...
# Company: Ag Growth International Inc. Ticker: AFN.TO
# sector: Industrials
#
# Processing row 14...
# Company: AGF Management Limited Ticker: AGF-B.TO
# sector: Financial Services
#
# Processing row 15...
# Company: Agnico Eagle Mines Limited Ticker: AEM.TO
# sector: Basic Materials
#
# Processing row 16...
# Company: Agrinam Acquisition Corporation Ticker: AGRI-U.TO
# sector: Financial Services
#
# Processing row 17...
# Company: Aimia Inc. Ticker: AIM.TO
# sector: Financial Services
#
# Processing row 18...
# Company: Air Canada Ticker: AC.TO
# sector: Industrials
#
# Processing row 19...
# Company: AirBoss of America Corp. Ticker: BOS.TO
# sector: Basic Materials
#
# Processing row 20...
# Company: AKITA Drilling Ltd. Ticker: AKT-A.TO
# sector: Energy
#
# Processing row 21...
# Company: Akumin Inc. Ticker: AKU.TO
# sector: Healthcare
#
# Processing row 22...
# Company: Alamos Gold Inc. Ticker: AGI.TO
# sector: Basic Materials
#
# Processing row 23...
# Company: Algoma Central Corporation Ticker: ALC.TO
# sector: Industrials
#
# Processing row 24...
# Company: Algoma Steel Group Inc. Ticker: ASTL.TO
# sector: Basic Materials
#
# Processing row 25...
# Company: Algonquin Power & Utilities Corp. Ticker: AQN.TO
# sector: Utilities
#
# Processing row 26...
# Company: Alimentation Couche-Tard Inc. Ticker: ATD.TO
# sector: Consumer Cyclical
#
# Processing row 27...
# Company: Alithya Group Inc. Ticker: ALYA.TO
# sector: Technology
#
# Processing row 28...
# Company: Allied Gold Corporation Ticker: AAUC.TO
# sector: Basic Materials
#
# Processing row 29...
# Company: Almaden Minerals Ltd. Ticker: AMM.TO
# sector: Basic Materials
#
# Processing row 30...
# Company: Almonty Industries Inc. Ticker: AII.TO
# sector: Basic Materials
#
# Processing row 31...
# Company: Alta Copper Corp. Ticker: ATCU.TO
# sector: Basic Materials
#
# Processing row 32...
# Company: AltaGas Ltd. Ticker: ALA.TO
# sector: Energy
#
# Processing row 33...
# Company: Altius Minerals Corporation Ticker: ALS.TO
# sector: Basic Materials
#
# Processing row 34...
# Company: Altius Renewable Royalties Corp. Ticker: ARR.TO
# sector: Utilities
#
# Processing row 35...
# Company: Altus Group Limited Ticker: AIF.TO
# sector: Real Estate
#
# Processing row 36...
# Company: American Hotel Income Properties REIT LP Ticker: HOT-UN.TO
# sector: Real Estate
#
# Processing row 37...
# Company: Americas Gold and Silver Corporation Ticker: USA.TO
# sector: Basic Materials
#
# Processing row 38...
# Company: Amerigo Resources Ltd. Ticker: ARG.TO
# sector: Basic Materials
#
# Processing row 39...
# Company: Anaergia Inc. Ticker: ANRG.TO
# sector: Industrials
#
# Processing row 40...
# Company: Andlauer Healthcare Group Inc. Ticker: AND.TO
# sector: Industrials
#
# Processing row 41...
# Company: Andrew Peller Limited Ticker: ADW-A.TO
# sector: Consumer Defensive
#
# Processing row 42...
# Company: Antibe Therapeutics Inc. Ticker: ATE.TO
# sector: Healthcare
#
# Processing row 43...
# Company: Appili Therapeutics Inc. Ticker: APLI.TO
# sector: Healthcare
#
# Processing row 44...
# Company: Aptose Biosciences Inc. Ticker: APS.TO
# sector: Healthcare
#
# Processing row 45...
# Company: ARC Resources Ltd. Ticker: ARX.TO
# sector: Energy
#
# Processing row 46...
# Company: Argonaut Gold Inc. Ticker: AR.TO
# sector: Basic Materials
#
# Processing row 47...
# Company: Aris Mining Corporation Ticker: ARIS.TO
# sector: Basic Materials
#
# Processing row 48...
# Company: Aritzia Inc. Ticker: ATZ.TO
# sector: Consumer Cyclical
#
# Processing row 49...
# Company: Arizona Metals Corp. Ticker: AMC.TO
# sector: Basic Materials
#
# Processing row 50...
# Company: Arizona Sonoran Copper Company Inc. Ticker: ASCU.TO
# sector: Basic Materials
#
# Processing row 51...
# Company: Arrow Canadian Advantage Alternative Class Ticker: ACAA.TO
# sector: Exchange Traded Fund
#
# Processing row 52...
# Company: Ascendant Resources Inc. Ticker: ASND.TO
# sector: Basic Materials
#
# Processing row 53...
# Company: Ascot Resources Ltd. Ticker: AOT.TO
# sector: Basic Materials
#
# Processing row 54...
# Company: ATCO Ltd. Ticker: ACO-X.TO
# sector: Utilities
#
# Processing row 55...
# Company: Athabasca Oil Corporation Ticker: ATH.TO
# sector: Energy
#
# Processing row 56...
# Company: Atrium Mortgage Investment Corporation Ticker: AI.TO
# sector: Financial Services
#
# Processing row 57...
# Company: ATS Corporation Ticker: ATS.TO
# sector: Industrials
#
# Processing row 58...
# Company: Augusta Gold Corp. Ticker: G.TO
# sector: Basic Materials
#
# Processing row 59...
# Company: Aura Minerals Inc. Ticker: ORA.TO
# sector: Basic Materials
#
# Processing row 60...
# Company: Aurora Cannabis Inc. Ticker: ACB.TO
# sector: Healthcare
#
# Processing row 61...
# Company: AutoCanada Inc. Ticker: ACQ.TO
# sector: Consumer Cyclical
#
# Processing row 62...
# Company: Auxly Cannabis Group Inc. Ticker: XLY.TO
# sector: Healthcare
#
# Processing row 63...
# Company: Avalon Advanced Materials Inc. Ticker: AVL.TO
# sector: Basic Materials
#
# Processing row 64...
# Company: Avant Brands Inc. Ticker: AVNT.TO
# sector: Healthcare
#
# Processing row 65...
# Company: Avicanna Inc. Ticker: AVCN.TO
# sector: Healthcare
#
# Processing row 66...
# Company: Avino Silver & Gold Mines Ltd. Ticker: ASM.TO
# sector: Basic Materials
#
# Processing row 67...
# Company: Axis Auto Finance Inc. Ticker: AXIS.TO
# sector: Financial Services
#
# Processing row 68...
# Company: Aya Gold & Silver Inc. Ticker: AYA.TO
# sector: Basic Materials
#
# Processing row 69...
# Company: Barrick Gold Corporation Ticker: ABX.TO
# sector: Basic Materials
#
# Processing row 70...
# Company: Golden Minerals Company Ticker: AUMN.TO
# sector: Basic Materials
#
# Processing row 71...
# Company: Healwell AI Inc. Ticker: AIDX.TO
# sector: Healthcare
#
# Processing row 72...
# Company: SNC-Lavalin Group Inc. Ticker: ATRL.TO
# sector: Industrials
#
# Processing row 73...
# Company: AirBoss of America Corp. Ticker: BOS.TO
# sector: Basic Materials
#
# Processing row 74...
# Company: B2Gold Corp. Ticker: BTO.TO
# sector: Basic Materials
#
# Processing row 75...
# Company: Badger Infrastructure Solutions Ltd. Ticker: BDGI.TO
# sector: Industrials
#
# Processing row 76...
# Company: Ballard Power Systems Inc. Ticker: BLDP.TO
# sector: Industrials
#
# Processing row 77...
# Company: Bank of Montreal Ticker: BMO.TO
# sector: Financial Services
#
# Processing row 78...
# Company: The Bank of Nova Scotia Ticker: BNS.TO
# sector: Financial Services
#
# Processing row 79...
# Company: Barrick Gold Corporation Ticker: ABX.TO
# sector: Basic Materials
#
# Processing row 80...
# Company: Bausch + Lomb Corporation Ticker: BLCO.TO
# sector: Healthcare
#
# Processing row 81...
# Company: Bausch Health Companies Inc. Ticker: BHC.TO
# sector: Healthcare
#
# Processing row 82...
# Company: Baylin Technologies Inc. Ticker: BYL.TO
# sector: Technology
#
# Processing row 83...
# Company: Baytex Energy Corp. Ticker: BTE.TO
# sector: Energy
#
# Processing row 84...
# Company: BCE Inc. Ticker: BCE.TO
# sector: Communication Services
#
# Processing row 85...
# Company: The Becker Milk Company Limited Ticker: BEK-B.TO
# sector: Real Estate
#
# Processing row 86...
# Company: Belo Sun Mining Corp Ticker: BSX.TO
# sector: Basic Materials
#
# Processing row 87...
# Company: Bengal Energy Ltd. Ticker: BNG.TO
# sector: Energy
#
# Processing row 88...
# Company: Big Banc Split Corp. Ticker: BNK.TO
# sector: Financial Services
#
# Processing row 89...
# Company: Big Pharma Split Corp. Ticker: PRM.TO
# sector: Financial Services
#
# Processing row 90...
# Company: Big Rock Brewery Inc. Ticker: BR.TO
# sector: Consumer Defensive
#
# Processing row 91...
# Company: Bip Investment Corporation Ticker: BIK-PA.TO
# sector: Financial Services
#
# Processing row 92...
# Company: Birchcliff Energy Ltd. Ticker: BIR.TO
# sector: Energy
#
# Processing row 93...
# Company: Bird Construction Inc. Ticker: BDT.TO
# sector: Industrials
#
# Processing row 94...
# Company: Bitfarms Ltd. Ticker: BITF.TO
# sector: Financial Services
#
# Processing row 95...
# Company: Black Diamond Group Limited Ticker: BDI.TO
# sector: Industrials
#
# Processing row 96...
# Company: Black Iron Inc. Ticker: BKI.TO
# sector: Basic Materials
#
# Processing row 97...
# Company: BlackBerry Limited Ticker: BB.TO
# sector: Technology
#
# Processing row 98...
# Company: Blackline Safety Corp. Ticker: BLN.TO
# sector: Technology
#
# Processing row 99...
# Company: BMTC Group Inc. Ticker: GBT.TO
# sector: Consumer Cyclical
#
# Processing row 100...
# Company: Boat Rocker Media Inc. Ticker: BRMI.TO
# sector: Communication Services
#
# Processing row 101...
# Company: Bombardier Inc. Ticker: BBD-B.TO
# sector: Industrials
#
# Processing row 102...
# Company: Bonterra Energy Corp. Ticker: BNE.TO
# sector: Energy
#
# Processing row 103...
# Company: Boralex Inc. Ticker: BLX.TO
# sector: Utilities
#
# Processing row 104...
# Company: Boyd Group Services Inc. Ticker: BYD.TO
# sector: Consumer Cyclical
#
# Processing row 105...
# Company: Bragg Gaming Group Inc. Ticker: BRAG.TO
# sector: Communication Services
#
# Processing row 106...
# Company: Bri-Chem Corp. Ticker: BRY.TO
# sector: Energy
#
# Processing row 107...
# Company: BriaCell Therapeutics Corp. Ticker: BCT.TO
# sector: Healthcare
#
# Processing row 108...
# Company: Bridgemarq Real Estate Services Inc. Ticker: BRE.TO
# sector: Real Estate
#
# Processing row 109...
# Company: Brompton Energy Split Corp. Ticker: ESP.TO
# Error processing row 109: 'legalType'
# Processing row 110...
# Company: Brompton Lifeco Split Corp. Ticker: LCS.TO
# sector: Financial Services
#
# Processing row 111...
# Company: Brompton Split Banc Corp. Ticker: SBC.TO
# sector: Financial Services
#
# Processing row 112...
# Company: Brookfield Asset Management Ltd. Ticker: BAM.TO
# sector: Financial Services
#
# Processing row 113...
# Company: Brookfield Business Corporation Ticker: BBUC.TO
# sector: Financial Services
#
# Processing row 114...
# Company: Brookfield Business Partners L.P. Ticker: BBU-UN.TO
# sector: Industrials
#
# Processing row 115...
# Company: Brookfield Corporation Ticker: BN.TO
# sector: Financial Services
#
# Processing row 116...
# Company: Brookfield Infrastructure Corporation Ticker: BIPC.TO
# sector: Utilities
#
# Processing row 117...
# Company: Brookfield Infrastructure Partners L.P. Ticker: BIP-UN.TO
# sector: Utilities
#
# Processing row 118...
# Company: Brookfield Office Properties Inc. Ticker: BPO-PX.TO
# sector: Real Estate
#
# Processing row 119...
# Company: Brookfield Property Preferred LP Ticker: BPYP-PA.TO
# Error processing row 119: 'legalType'
# Processing row 120...
# Company: Brookfield Property Partners L.P. Ticker: BPYPP
# sector: Real Estate
#
# Processing row 121...
# Company: Brookfield Reinsurance Ltd. Ticker: BNRE
# sector: Financial Services
#
# Processing row 122...
# Company: Brookfield Renewable Corporation Ticker: BEPC.TO
# sector: Utilities
#
# Processing row 123...
# Company: Brookfield Renewable Partners L.P. Ticker: BEP-UN.TO
# sector: Utilities
#
# Processing row 124...
# Company: Brookfield Renewable Power Preferred Equity Inc. Ticker: BRF-PA.TO
# sector: Utilities
#
# Processing row 125...
# Company: BRP Inc. Ticker: DOO.TO
# sector: Consumer Cyclical
#
# Processing row 126...
# Company: Buhler Industries Inc. Ticker: BUI.TO
# sector: Industrials
#
# Processing row 127...
# Company: Burcon NutraScience Corporation Ticker: BU.TO
# sector: Consumer Defensive
#
# Processing row 128...
# Company: Canadian Banc Corp. Ticker: BK.TO
# sector: Financial Services
#
# Processing row 129...
# Company: Else Nutrition Holdings Inc. Ticker: BABY.TO
# sector: Consumer Defensive
#
# Processing row 130...
# Company: CAE Inc. Ticker: CAE.TO
# sector: Industrials
#
# Processing row 131...
# Company: The Caldwell Partners International Inc. Ticker: CWL.TO
# sector: Industrials
#
# Processing row 132...
# Company: Calfrac Well Services Ltd. Ticker: CFW.TO
# sector: Energy
#
# Processing row 133...
# Company: Calian Group Ltd. Ticker: CGY.TO
# sector: Industrials
#
# Processing row 134...
# Company: Calibre Mining Corp. Ticker: CXB.TO
# sector: Basic Materials
#
# Processing row 135...
# Company: Cameco Corporation Ticker: CCO.TO
# sector: Energy
#
# Processing row 136...
# Company: Canaccord Genuity Group Inc. Ticker: CF.TO
# sector: Financial Services
#
# Processing row 137...
# Company: Canacol Energy Ltd Ticker: CNE.TO
# sector: Energy
#
# Processing row 138...
# Company: Canada Goose Holdings Inc. Ticker: GOOS.TO
# sector: Consumer Cyclical
#
# Processing row 139...
# Company: Canadian Banc Corp. Ticker: BK.TO
# sector: Financial Services
#
# Processing row 140...
# Company: Canadian General Investments Ord Ticker: CGI.TO
# sector: Financial Services
#
# Processing row 141...
# Company: Canadian Imperial Bank of Commerce Ticker: CM.TO
# sector: Financial Services
#
# Processing row 142...
# Company: Canadian Life Companies Split Corp. Ticker: LFE.TO
# sector: Financial Services
#
# Processing row 143...
# Company: Canadian National Railway Company Ticker: CNR.TO
# sector: Industrials
#
# Processing row 144...
# Company: Canadian Natural Resources Limited Ticker: CNQ.TO
# sector: Energy
#
# Processing row 145...
# Company: Canadian Pacific Kansas City Limited Ticker: CP.TO
# sector: Industrials
#
# Processing row 146...
# Company: Canadian Tire Corporation, Limited Ticker: CTC-A.TO
# sector: Consumer Cyclical
#
# Processing row 147...
# Company: Canadian Utilities Limited Ticker: CU.TO
# sector: Utilities
#
# Processing row 148...
# Company: Canadian Western Bank Ticker: CWB.TO
# sector: Financial Services
#
# Processing row 149...
# Company: Canagold Resources Ltd. Ticker: CCM.TO
# sector: Basic Materials
#
# Processing row 150...
# Company: Canfor Corporation Ticker: CFP.TO
# sector: Basic Materials
#
# Processing row 151...
# Company: Canfor Pulp Products Inc. Ticker: CFX.TO
# sector: Basic Materials
#
# Processing row 152...
# Company: Canlan Ice Sports Corp. Ticker: ICE.TO
# sector: Consumer Cyclical
#
# Processing row 153...
# Company: Canopy Growth Corporation Ticker: WEED.TO
# sector: Healthcare
#
# Processing row 154...
# Company: Capital Power Corporation Ticker: CPX.TO
# sector: Utilities
#
# Processing row 155...
# Company: Capstone Copper Corp. Ticker: CS.TO
# sector: Basic Materials
#
# Processing row 156...
# Company: Capstone Infrastructure Corporation Ticker: CSE-PA.TO
# sector: Utilities
#
# Processing row 157...
# Company: Cardinal Energy Ltd. Ticker: CJ.TO
# sector: Energy
#
# Processing row 158...
# Company: Cardiol Therapeutics Inc. Ticker: CRDL.TO
# sector: Healthcare
#
# Processing row 159...
# Company: CareRx Corporation Ticker: CRRX.TO
# sector: Healthcare
#
# Processing row 160...
# Company: Cargojet Inc. Ticker: CJT.TO
# sector: Industrials
#
# Processing row 161...
# Company: Caribbean Utilities Company, Ltd. Ticker: CUP-U.TO
# sector: Utilities
#
# Processing row 162...
# Company: Cascades Inc. Ticker: CAS.TO
# sector: Consumer Cyclical
#
# Processing row 163...
# Company: Cathedral Energy Services Ltd. Ticker: CET.TO
# sector: Energy
#
# Processing row 164...
# Company: CCL Industries Inc. Ticker: CCL-B.TO
# sector: Consumer Cyclical
#
# Processing row 165...
# Company: Celestica Inc. Ticker: CLS.TO
# sector: Technology
#
# Processing row 166...
# Company: Cenovus Energy Inc. Ticker: CVE.TO
# sector: Energy
#
# Processing row 167...
# Company: Centamin plc Ticker: CEE.TO
# sector: Basic Materials
#
# Processing row 168...
# Company: Centerra Gold Inc. Ticker: CG.TO
# sector: Basic Materials
#
# Processing row 169...
# Company: Century Global Commodities Corporation Ticker: CNT.TO
# sector: Consumer Defensive
#
# Processing row 170...
# Company: Ceres Global Ag Corp. Ticker: CRP.TO
# sector: Consumer Defensive
#
# Processing row 171...
# Company: Dayforce Inc. Ticker: CDAY.TO
# sector: Technology
#
# Processing row 172...
# Company: CES Energy Solutions Corp. Ticker: CEU.TO
# sector: Energy
#
# Processing row 173...
# Company: CGI Inc. Ticker: GIB-A.TO
# sector: Technology
#
# Processing row 174...
# Company: Champion Iron Limited Ticker: CIA.TO
# sector: Basic Materials
#
# Processing row 175...
# Company: Charlotte's Web Holdings, Inc. Ticker: CWEB.TO
# sector: Healthcare
#
# Processing row 176...
# Company: Chartwell Retirement Residences Ticker: CSH-UN.TO
# sector: Real Estate
#
# Processing row 177...
# Company: Chesswood Group Limited Ticker: CHW.TO
# sector: Financial Services
#
# Processing row 178...
# Company: China Gold International Resources Corp. Ltd. Ticker: CGG.TO
# sector: Basic Materials
#
# Processing row 179...
# Company: Chorus Aviation Inc. Ticker: CHR.TO
# sector: Industrials
#
# Processing row 180...
# Company: CI Financial Corp. Ticker: CIX.TO
# sector: Financial Services
#
# Processing row 181...
# Company: CI Global Asset Allocation Private Pool ETF Ticker: CGAA.TO
# sector: Exchange Traded Fund
#
# Processing row 182...
# Company: CI Global High Yield Credit Private Pool Ticker: CGHY.TO
# Error processing row 182: 'legalType'
# Processing row 183...
# Company: CI Global Infrastructure Private Pool Ticker: CINF.TO
# sector: Exchange Traded Fund
#
# Processing row 184...
# Company: CI Global Real Asset Private Pool Ticker: CGRA.TO
# sector: Exchange Traded Fund
#
# Processing row 185...
# Company: CI Global REIT Private Pool Ticker: CGRE.TO
# sector: Exchange Traded Fund
#
# Processing row 186...
# Company: CIBC Conservative Fixed Income Pool A Ticker: 0P0001IMXJ.TO
# Error processing row 186: 'legalType'
# Processing row 187...
# Company: CIBC Core Fixed Income Pool Ticker: CCRE.TO
# sector: Exchange Traded Fund
#
# Processing row 188...
# Company: CIBC Core Plus Fixed Income Pool O Ticker: 0P0001IMXR.TO
# Error processing row 188: 'legalType'
# Processing row 189...
# Company: Cineplex Inc. Ticker: CGX.TO
# sector: Communication Services
#
# Processing row 190...
# Company: Cipher Pharmaceuticals Inc. Ticker: CPH.TO
# sector: Healthcare
#
# Processing row 191...
# Company: Clairvest Group Inc. Ticker: CVG.TO
# sector: Financial Services
#
# Processing row 192...
# Company: Clarke Inc. Ticker: CKI.TO
# sector: Consumer Cyclical
#
# Processing row 193...
# Company: Co-operators General Insurance Co Ticker: CCS-PC.TO
# Error processing row 193: 'legalType'
# Processing row 194...
# Company: Cogeco Communications Inc. Ticker: CCA.TO
# sector: Communication Services
#
# Processing row 195...
# Company: Cogeco Communications Inc. Ticker: CCA.TO
# sector: Communication Services
#
# Processing row 196...
# Company: Colabor Group Inc. Ticker: GCL.TO
# sector: Consumer Defensive
#
# Processing row 197...
# Company: Collective Mining Ltd. Ticker: CNL.TO
# sector: Basic Materials
#
# Processing row 198...
# Company: Colliers International Group Inc. Ticker: CIGI.TO
# sector: Real Estate
#
# Processing row 199...
# Company: Commerce Split Corp Ticker: YCM-PA.TO
# Error processing row 199: 'legalType'
# Processing row 200...
# Company: Computer Modelling Group Ltd. Ticker: CMG.TO
# sector: Technology
#
# Processing row 201...
# Company: Condor Energies Inc. Ticker: CDR.TO
# sector: Energy
#
# Processing row 202...
# Company: Condor Gold Plc Ticker: COG.TO
# sector: Basic Materials
#
# Processing row 203...
# Company: Conifex Timber Inc. Ticker: CFF.TO
# sector: Basic Materials
#
# Processing row 204...
# Company: Constellation Software Inc. Ticker: CSU.TO
# sector: Technology
#
# Processing row 205...
# Company: Converge Technology Solutions Corp. Ticker: CTS.TO
# sector: Technology
#
# Processing row 206...
# Company: Copperleaf Technologies Inc. Ticker: CPLF.TO
# sector: Technology
#
# Processing row 207...
# Company: Corby Spirit and Wine Limited Ticker: CSW-A.TO
# sector: Consumer Defensive
#
# Processing row 208...
# Company: Corus Entertainment Inc. Ticker: CJR-B.TO
# sector: Communication Services
#
# Processing row 209...
# Company: Coveo Solutions Inc. Ticker: CVO.TO
# sector: Technology
#
# Processing row 210...
# Company: Crescent Point Energy Corp. Ticker: CPG.TO
# sector: Energy
#
# Processing row 211...
# Company: Crescita Therapeutics Inc. Ticker: CTX.TO
# sector: Healthcare
#
# Processing row 212...
# Company: Crew Energy Inc. Ticker: CR.TO
# sector: Energy
#
# Processing row 213...
# Company: Cronos Group Inc. Ticker: CRON.TO
# sector: Healthcare
#
# Processing row 214...
# Company: Crown Capital Partners Inc. Ticker: CRWN.TO
# sector: Financial Services
#
# Processing row 215...
# Company: CU Inc Ticker: CIU-PC.TO
# Error processing row 215: 'legalType'
# Processing row 216...
# Company: Curaleaf Holdings, Inc. Ticker: CURA.TO
# sector: Healthcare
#
# Processing row 217...
# Company: Currency Exchange International, Corp. Ticker: CXI.TO
# sector: Financial Services
#
# Processing row 218...
# Company: Cymbria Corporation Ticker: CYB.TO
# sector: Financial Services
#
# Processing row 219...
# Company: ADF Group Inc. Ticker: DRX.TO
# sector: Industrials
#
# Processing row 220...
# Company: BRP Inc. Ticker: DOO.TO
# sector: Consumer Cyclical
#
# Processing row 221...
# Company: D-BOX Technologies Inc. Ticker: DBO.TO
# sector: Technology
#
# Processing row 222...
# Company: D2L Inc. Ticker: DTOL.TO
# sector: Technology
#
# Processing row 223...
# Company: DATA Communications Management Corp. Ticker: DCM.TO
# sector: Industrials
#
# Processing row 224...
# Company: Definity Financial Corporation Ticker: DFY.TO
# sector: Financial Services
#
# Processing row 225...
# Company: Delta 9 Cannabis Inc. Ticker: DN.TO
# sector: Healthcare
#
# Processing row 226...
# Company: Denison Mines Corp. Ticker: DML.TO
# sector: Energy
#
# Processing row 227...
# Company: dentalcorp Holdings Ltd. Ticker: DNTL.TO
# sector: Healthcare
#
# Processing row 228...
# Company: The Descartes Systems Group Inc. Ticker: DSG.TO
# sector: Technology
#
# Processing row 229...
# Company: Dexterra Group Inc. Ticker: DXT.TO
# sector: Industrials
#
# Processing row 230...
# Company: DIRTT Environmental Solutions Ltd. Ticker: DRT.TO
# sector: Industrials
#
# Processing row 231...
# Company: Discovery Silver Corp. Ticker: DSV.TO
# sector: Basic Materials
#
# Processing row 232...
# Company: Diversified Royalty Corp. Ticker: DIV.TO
# sector: Industrials
#
# Processing row 233...
# Company: Dividend 15 Split Corp. Ticker: DFN.TO
# sector: Financial Services
#
# Processing row 234...
# Company: Dividend 15 Split Corp. II Ticker: DF.TO
# sector: Financial Services
#
# Processing row 235...
# Company: Dividend Growth Split Corp. Ticker: DGS.TO
# sector: Financial Services
#
# Processing row 236...
# Company: Dividend Select 15 Corp. Ticker: DS.TO
# sector: Financial Services
#
# Processing row 237...
# Company: Docebo Inc. Ticker: DCBO.TO
# sector: Technology
#
# Processing row 238...
# Company: Dollarama Inc. Ticker: DOL.TO
# sector: Consumer Defensive
#
# Processing row 239...
# Company: Doman Building Materials Group Ltd. Ticker: DBM.TO
# sector: Industrials
#
# Processing row 240...
# Company: Dominion Lending Centres Inc. Ticker: DLCG.TO
# sector: Financial Services
#
# Processing row 241...
# Company: Dorel Industries Inc. Ticker: DII-B.TO
# sector: Consumer Cyclical
#
# Processing row 242...
# Company: Dream Unlimited Corp. Ticker: DRM.TO
# sector: Real Estate
#
# Processing row 243...
# Company: Dundee Corporation Ticker: DC-A.TO
# sector: Basic Materials
#
# Processing row 244...
# Company: Dundee Precious Metals Inc. Ticker: DPM.TO
# sector: Basic Materials
#
# Processing row 245...
# Company: Dye & Durham Limited Ticker: DND.TO
# sector: Technology
#
# Processing row 246...
# Company: dynaCERT Inc. Ticker: DYA.TO
# sector: Industrials
#
# Processing row 247...
# Company: Dynacor Group Inc. Ticker: DNG.TO
# sector: Basic Materials
#
# Processing row 248...
# Company: Medical Facilities Corporation Ticker: DR.TO
# sector: Healthcare
#
# Processing row 249...
# Company: Star Diamond Corporation Ticker: DIAM.TO
# sector: Basic Materials
#
# Processing row 250...
# Company: Brompton Energy Split Corp. Ticker: ESP.TO
# Error processing row 250: 'legalType'
# Processing row 251...
# Company: E Split Corp. Ticker: ENS.TO
# sector: Financial Services
#
# Processing row 252...
# Company: E-L Financial Corporation Limited Ticker: ELF.TO
# sector: Financial Services
#
# Processing row 253...
# Company: East Side Games Group Inc. Ticker: EAGR.TO
# sector: Communication Services
#
# Processing row 254...
# Company: Eastern Platinum Limited Ticker: ELR.TO
# sector: Basic Materials
#
# Processing row 255...
# Company: ECN Capital Corp. Ticker: ECN.TO
# sector: Financial Services
#
# Processing row 256...
# Company: Ecora Resources PLC Ticker: ECRAF
# sector: Basic Materials
#
# Processing row 257...
# Company: EcoSynthetix Inc. Ticker: ECO.TO
# sector: Basic Materials
#
# Processing row 258...
# Company: Eldorado Gold Corporation Ticker: ELD.TO
# sector: Basic Materials
#
# Processing row 259...
# Company: Electrovaya Inc. Ticker: ELVA.TO
# sector: Industrials
#
# Processing row 260...
# Company: Element Fleet Management Corp. Ticker: EFN.TO
# sector: Industrials
#
# Processing row 261...
# Company: Eloro Resources Ltd. Ticker: ELO.TO
# sector: Basic Materials
#
# Processing row 262...
# Company: Else Nutrition Holdings Inc. Ticker: BABY.TO
# sector: Consumer Defensive
#
# Processing row 263...
# Company: Emera Incorporated Ticker: EMA.TO
# sector: Utilities
#
# Processing row 264...
# Company: Empire Company Limited Ticker: EMP-A.TO
# sector: Consumer Defensive
#
# Processing row 265...
# Company: Enbridge Inc. Ticker: ENB.TO
# sector: Energy
#
# Processing row 266...
# Company: Endeavour Mining plc Ticker: EDV.TO
# sector: Basic Materials
#
# Processing row 267...
# Company: Endeavour Silver Corp. Ticker: EDR.TO
# sector: Basic Materials
#
# Processing row 268...
# Company: Enerflex Ltd. Ticker: EFX.TO
# sector: Energy
#
# Processing row 269...
# Company: Energy Fuels Inc. Ticker: EFR.TO
# sector: Energy
#
# Processing row 270...
# Company: Enerplus Corporation Ticker: ERF.TO
# sector: Energy
#
# Processing row 271...
# Company: Enghouse Systems Limited Ticker: ENGH.TO
# sector: Technology
#
# Processing row 272...
# Company: Ensign Energy Services Inc. Ticker: ESI.TO
# sector: Energy
#
# Processing row 273...
# Company: Enterprise Group, Inc. Ticker: E.TO
# sector: Energy
#
# Processing row 274...
# Company: Enthusiast Gaming Holdings Inc. Ticker: EGLX.TO
# sector: Communication Services
#
# Processing row 275...
# Company: Entrée Resources Ltd. Ticker: ETG.TO
# sector: Basic Materials
#
# Processing row 276...
# Company: EQB Inc. Ticker: EQB.TO
# sector: Financial Services
#
# Processing row 277...
# Company: Equinox Gold Corp. Ticker: EQX.TO
# sector: Basic Materials
#
# Processing row 278...
# Company: Erdene Resource Development Corporation Ticker: ERD.TO
# sector: Basic Materials
#
# Processing row 279...
# Company: Ero Copper Corp. Ticker: ERO.TO
# sector: Basic Materials
#
# Processing row 280...
# Company: Eupraxia Pharmaceuticals Inc. Ticker: EPRX.TO
# sector: Healthcare
#
# Processing row 281...
# Company: Euro Sun Mining Inc. Ticker: ESM.TO
# sector: Basic Materials
#
# Processing row 282...
# Company: Evertz Technologies Limited Ticker: ET.TO
# sector: Technology
#
# Processing row 283...
# Company: Excellon Resources Inc. Ticker: EXN.TO
# sector: Basic Materials
#
# Processing row 284...
# Company: Excelsior Mining Corp. Ticker: MIN.TO
# sector: Basic Materials
#
# Processing row 285...
# Company: Exchange Income Corporation Ticker: EIF.TO
# sector: Industrials
#
# Processing row 286...
# Company: Exco Technologies Limited Ticker: XTC.TO
# sector: Consumer Cyclical
#
# Processing row 287...
# Company: Exro Technologies Inc. Ticker: EXRO.TO
# sector: Industrials
#
# Processing row 288...
# Company: Extendicare Inc. Ticker: EXE.TO
# sector: Healthcare
#
# Processing row 289...
# Company: Silver Elephant Mining Corp. Ticker: ELEF.TO
# sector: Basic Materials
#
# Processing row 290...
# Company: Spectral Medical Inc. Ticker: EDT.TO
# sector: Healthcare
#
# Processing row 291...
# Company: Fairfax Financial Holdings Limited Ticker: FFH.TO
# sector: Financial Services
#
# Processing row 292...
# Company: Fairfax India Holdings Corporation Ticker: FIH-U.TO
# sector: Financial Services
#
# Processing row 293...
# Company: FansUnite Entertainment Inc. Ticker: FANS.TO
# sector: Consumer Cyclical
#
# Processing row 294...
# Company: Faraday Copper Corp. Ticker: FDY.TO
# sector: Basic Materials
#
# Processing row 295...
# Company: Farmers Edge Inc. Ticker: FDGE.TO
# sector: Technology
#
# Processing row 296...
# Company: Fennec Pharmaceuticals Inc. Ticker: FENC
# sector: Healthcare
#
# Processing row 297...
# Company: FG Acquisition Corp. Ticker: FGAA-U.TO
# sector: Financial Services
#
# Processing row 298...
# Company: Fiera Capital Corporation Ticker: FSZ.TO
# sector: Financial Services
#
# Processing row 299...
# Company: Filo Corp. Ticker: FIL.TO
# sector: Basic Materials
#
# Processing row 300...
# Company: Financial 15 Split Corp. Ticker: FTN.TO
# sector: Financial Services
#
# Processing row 301...
# Company: Finning International Inc. Ticker: FTT.TO
# sector: Industrials
#
# Processing row 302...
# Company: Firan Technology Group Corporation Ticker: FTG.TO
# sector: Industrials
#
# Processing row 303...
# Company: Firm Capital Mortgage Investment Corporation Ticker: FC.TO
# sector: Financial Services
#
# Processing row 304...
# Company: First Majestic Silver Corp. Ticker: FR.TO
# sector: Basic Materials
#
# Processing row 305...
# Company: First Mining Gold Corp. Ticker: FF.TO
# sector: Basic Materials
#
# Processing row 306...
# Company: First National Financial Corporation Ticker: FN.TO
# sector: Financial Services
#
# Processing row 307...
# Company: First Quantum Minerals Ltd. Ticker: FM.TO
# sector: Basic Materials
#
# Processing row 308...
# Company: FirstService Corporation Ticker: FSV.TO
# sector: Real Estate
#
# Processing row 309...
# Company: Fission Uranium Corp. Ticker: FCU.TO
# sector: Energy
#
# Processing row 310...
# Company: Flint Corp. Ticker: FLNT.TO
# sector: Energy
#
# Processing row 311...
# Company: Flow Beverage Corp. Ticker: FLOW.TO
# sector: Consumer Defensive
#
# Processing row 312...
# Company: Foraco International SA Ticker: FAR.TO
# sector: Basic Materials
#
# Processing row 313...
# Company: Foran Mining Corporation Ticker: FOM.TO
# sector: Basic Materials
#
# Processing row 314...
# Company: Forsys Metals Corp. Ticker: FSY.TO
# sector: Basic Materials
#
# Processing row 315...
# Company: Fortis Inc. Ticker: FTS.TO
# sector: Utilities
#
# Processing row 316...
# Company: Fortuna Silver Mines Inc. Ticker: FVI.TO
# sector: Basic Materials
#
# Processing row 317...
# Company: Fortune Minerals Limited Ticker: FT.TO
# sector: Basic Materials
#
# Processing row 318...
# Company: Forza Petroleum Limited Ticker: FORZ.TO
# sector: Energy
#
# Processing row 319...
# Company: Franco-Nevada Corporation Ticker: FNV.TO
# sector: Basic Materials
#
# Processing row 320...
# Company: Freegold Ventures Limited Ticker: FVL.TO
# sector: Basic Materials
#
# Processing row 321...
# Company: Freehold Royalties Ltd. Ticker: FRU.TO
# sector: Energy
#
# Processing row 322...
# Company: Frontera Energy Corporation Ticker: FEC.TO
# sector: Energy
#
# Processing row 323...
# Company: Fury Gold Mines Limited Ticker: FURY.TO
# sector: Basic Materials
#
# Processing row 324...
# Company: Goodfood Market Corp. Ticker: FOOD.TO
# sector: Consumer Cyclical
#
# Processing row 325...
# Company: North American Financial 15 Split Corp. Ticker: FFN.TO
# sector: Financial Services
#
# Processing row 326...
# Company: US Financial 15 Split Corp Ticker: FTU.TO
# sector: Financial Services
#
# Processing row 327...
# Company: VerticalScope Holdings Inc. Ticker: FORA.TO
# sector: Communication Services
#
# Processing row 328...
# Company: Augusta Gold Corp. Ticker: G.TO
# sector: Basic Materials
#
# Processing row 329...
# Company: BMTC Group Inc. Ticker: GBT.TO
# sector: Consumer Cyclical
#
# Processing row 330...
# Company: Canada Goose Holdings Inc. Ticker: GOOS.TO
# sector: Consumer Cyclical
#
# Processing row 331...
# Company: CGI Inc. Ticker: GIB-A.TO
# sector: Technology
#
# Processing row 332...
# Company: Colabor Group Inc. Ticker: GCL.TO
# sector: Consumer Defensive
#
# Processing row 333...
# Company: G Mining Ventures Corp. Ticker: GMINF
# sector: Basic Materials
#
# Processing row 334...
# Company: Galaxy Digital Holdings Ltd. Ticker: GLXY.TO
# sector: Financial Services
#
# Processing row 335...
# Company: Galiano Gold Inc. Ticker: GAU.TO
# sector: Basic Materials
#
# Processing row 336...
# Company: Gamehost Inc. Ticker: GH.TO
# sector: Consumer Cyclical
#
# Processing row 337...
# Company: Gamelancer Media Corp. Ticker: GAMGF
# sector: Communication Services
#
# Processing row 338...
# Company: Gatos Silver, Inc. Ticker: GATO.TO
# sector: Basic Materials
#
# Processing row 339...
# Company: GDI Integrated Facility Services Inc. Ticker: GDI.TO
# sector: Industrials
#
# Processing row 340...
# Company: Gear Energy Ltd. Ticker: GXE.TO
# sector: Energy
#
# Processing row 341...
# Company: Generation Mining Limited Ticker: GENM.TO
# sector: Basic Materials
#
# Processing row 342...
# Company: Genesis Land Development Corp. Ticker: GDC.TO
# sector: Real Estate
#
# Processing row 343...
# Company: Geodrill Limited Ticker: GEO.TO
# sector: Basic Materials
#
# Processing row 344...
# Company: George Weston Limited Ticker: WN.TO
# sector: Consumer Defensive
#
# Processing row 345...
# Company: GFL Environmental Inc. Ticker: GFL.TO
# sector: Industrials
#
# Processing row 346...
# Company: Gibson Energy Inc. Ticker: GEI.TO
# sector: Energy
#
# Processing row 347...
# Company: Gildan Activewear Inc. Ticker: GIL.TO
# sector: Consumer Cyclical
#
# Processing row 348...
# Company: Givex Corp. Ticker: GIVX.TO
# sector: Technology
#
# Processing row 349...
# Company: Glacier Media Inc. Ticker: GVC.TO
# sector: Communication Services
#
# Processing row 350...
# Company: GLG Life Tech Corporation Ticker: GLG.TO
# sector: Consumer Defensive
#
# Processing row 351...
# Company: Global Atomic Corporation Ticker: GLO.TO
# sector: Basic Materials
#
# Processing row 352...
# Company: Global Dividend Growth Split Corp. Ticker: GDV.TO
# sector: Financial Services
#
# Processing row 353...
# Company: Global Education Communities Corp. Ticker: GEC.TO
# sector: Consumer Defensive
#
# Processing row 354...
# Company: Globex Mining Enterprises Inc. Ticker: GMX.TO
# sector: Basic Materials
#
# Processing row 355...
# Company: goeasy Ltd. Ticker: GSY.TO
# sector: Financial Services
#
# Processing row 356...
# Company: GoGold Resources Inc. Ticker: GGD.TO
# sector: Basic Materials
#
# Processing row 357...
# Company: Gold Mountain Mining Corp. Ticker: GMTN.TO
# sector: Basic Materials
#
# Processing row 358...
# Company: Gold Springs Resource Corp. Ticker: GRC.TO
# sector: Basic Materials
#
# Processing row 359...
# Company: Golden Minerals Company Ticker: AUMN.TO
# sector: Basic Materials
#
# Processing row 360...
# Company: Goldgroup Mining Inc. Ticker: GGA.TO
# sector: Basic Materials
#
# Processing row 361...
# Company: GoldMining Inc. Ticker: GOLD.TO
# sector: Basic Materials
#
# Processing row 362...
# Company: Goldmoney Inc. Ticker: XAU.TO
# sector: Financial Services
#
# Processing row 363...
# Company: Goodfellow Inc. Ticker: GDL.TO
# sector: Basic Materials
#
# Processing row 364...
# Company: Goodfood Market Corp. Ticker: FOOD.TO
# sector: Consumer Cyclical
#
# Processing row 365...
# Company: Gran Tierra Energy Inc. Ticker: GTE.TO
# sector: Energy
#
# Processing row 366...
# Company: Great-West Lifeco Inc. Ticker: GWO.TO
# sector: Financial Services
#
# Processing row 367...
# Company: GreenFirst Forest Products Inc. Ticker: GFP.TO
# sector: Basic Materials
#
# Processing row 368...
# Company: Greenlane Renewables Inc. Ticker: GRN.TO
# sector: Industrials
#
# Processing row 369...
# Company: Guardian Capital Group Limited Ticker: GCG-A.TO
# sector: Financial Services
#
# Processing row 370...
# Company: Guardian Directed Equity Path Portfolio Ticker: GDEP.TO
# sector: Exchange Traded Fund
#
# Processing row 371...
# Company: Guardian Directed Premium Yield Portfolio Ticker: GDPY.TO
# sector: Exchange Traded Fund
#
# Processing row 372...
# Company: GURU Organic Energy Corp. Ticker: GURU.TO
# sector: Consumer Defensive
#
# Processing row 373...
# Company: Knight Therapeutics Inc. Ticker: GUD.TO
# sector: Healthcare
#
# Processing row 374...
# Company: NanoXplore Inc. Ticker: GRA.TO
# sector: Basic Materials
#
# Processing row 375...
# Company: Tantalus Systems Holding Inc. Ticker: GRID.TO
# sector: Industrials
#
# Processing row 376...
# Company: American Hotel Income Properties REIT LP Ticker: HOT-UN.TO
# sector: Real Estate
#
# Processing row 377...
# Company: Haivision Systems Inc. Ticker: HAI.TO
# sector: Technology
#
# Processing row 378...
# Company: Hamilton Thorne Ltd. Ticker: HTL.TO
# sector: Healthcare
#
# Processing row 379...
# Company: Hammond Manufacturing Company Limited Ticker: HMM-A.TO
# sector: Industrials
#
# Processing row 380...
# Company: Hammond Power Solutions Inc. Ticker: HPS-A.TO
# sector: Industrials
#
# Processing row 381...
# Company: Headwater Exploration Inc. Ticker: HWX.TO
# sector: Energy
#
# Processing row 382...
# Company: Healwell AI Inc. Ticker: AIDX.TO
# sector: Healthcare
#
# Processing row 383...
# Company: Helios Fairfax Partners Corporation Ticker: HFPC-U.TO
# sector: Financial Services
#
# Processing row 384...
# Company: Helix BioPharma Corp. Ticker: HBP.TO
# sector: Healthcare
#
# Processing row 385...
# Company: Héroux-Devtek Inc. Ticker: HRX.TO
# sector: Industrials
#
# Processing row 386...
# Company: None Ticker: HEXO?P=HEXO
# Error processing row 386: 'legalType'
# Processing row 387...
# Company: High Arctic Energy Services Inc Ticker: HWO.TO
# sector: Energy
#
# Processing row 388...
# Company: High Liner Foods Incorporated Ticker: HLF.TO
# sector: Consumer Defensive
#
# Processing row 389...
# Company: HLS Therapeutics Inc. Ticker: HLS.TO
# sector: Healthcare
#
# Processing row 390...
# Company: Horizonte Minerals Plc Ticker: HZM.TO
# sector: Basic Materials
#
# Processing row 391...
# Company: Hudbay Minerals Inc. Ticker: HBM.TO
# sector: Basic Materials
#
# Processing row 392...
# Company: Hut 8 Corp. Ticker: HUT.TO
# sector: Financial Services
#
# Processing row 393...
# Company: Hydro One Limited Ticker: H.TO
# sector: Utilities
#
# Processing row 394...
# Company: Canlan Ice Sports Corp. Ticker: ICE.TO
# sector: Consumer Cyclical
#
# Processing row 395...
# Company: i-80 Gold Corp. Ticker: IAU.TO
# sector: Basic Materials
#
# Processing row 396...
# Company: i3 Energy Plc Ticker: ITE.TO
# sector: Energy
#
# Processing row 397...
# Company: iA Financial Corporation Inc. Ticker: IAG.TO
# sector: Financial Services
#
# Processing row 398...
# Company: IA Wealth Enhanced Bond Pool B Ticker: 0P0001K5CW.TO
# Error processing row 398: 'legalType'
# Processing row 399...
# Company: IAMGOLD Corporation Ticker: IMG.TO
# sector: Basic Materials
#
# Processing row 400...
# Company: IBI Group Holdings Limited Ticker: 1547.HK
# sector: Industrials
#
# Processing row 401...
# Company: iFabric Corp. Ticker: IFA.TO
# sector: Consumer Cyclical
#
# Processing row 402...
# Company: IGM Financial Inc. Ticker: IGM.TO
# sector: Financial Services
#
# Processing row 403...
# Company: illumin Holdings Inc. Ticker: ILLM.TO
# sector: Communication Services
#
# Processing row 404...
# Company: Imperial Metals Corporation Ticker: III.TO
# sector: Basic Materials
#
# Processing row 405...
# Company: Imperial Oil Limited Ticker: IMO.TO
# sector: Energy
#
# Processing row 406...
# Company: Indigo Books & Music Inc. Ticker: IDG.TO
# sector: Consumer Cyclical
#
# Processing row 407...
# Company: iA Financial Corporation Inc. Ticker: IAG.TO
# sector: Financial Services
#
# Processing row 408...
# Company: Information Services Corporation Ticker: ISV.TO
# sector: Industrials
#
# Processing row 409...
# Company: Innergex Renewable Energy Inc. Ticker: INE.TO
# sector: Utilities
#
# Processing row 410...
# Company: InPlay Oil Corp. Ticker: IPO.TO
# sector: Energy
#
# Processing row 411...
# Company: Intact Financial Corporation Ticker: IFC.TO
# sector: Financial Services
#
# Processing row 412...
# Company: IntelGenx Technologies Corp. Ticker: IGX.TO
# sector: Healthcare
#
# Processing row 413...
# Company: Intellipharmaceutics International Inc. Ticker: IPCI.TO
# sector: Healthcare
#
# Processing row 414...
# Company: Interfor Corporation Ticker: IFP.TO
# sector: Basic Materials
#
# Processing row 415...
# Company: Intermap Technologies Corporation Ticker: IMP.TO
# sector: Technology
#
# Processing row 416...
# Company: International Petroleum Corporation Ticker: IPCO.TO
# sector: Energy
#
# Processing row 417...
# Company: International Tower Hill Mines Ltd. Ticker: ITH.TO
# sector: Basic Materials
#
# Processing row 418...
# Company: Invesque Inc. Ticker: IVQ.TO
# sector: Real Estate
#
# Processing row 419...
# Company: Ivanhoe Electric Inc. Ticker: IE.TO
# sector: Basic Materials
#
# Processing row 420...
# Company: Ivanhoe Mines Ltd. Ticker: IVN.TO
# sector: Basic Materials
#
# Processing row 421...
# Company: Purpose Global Bond Fund Ticker: BND.TO
# sector: Exchange Traded Fund
#
# Processing row 422...
# Company: Jaguar Mining Inc. Ticker: JAG.TO
# sector: Basic Materials
#
# Processing row 423...
# Company: Jamieson Wellness Inc. Ticker: JWEL.TO
# sector: Consumer Defensive
#
# Processing row 424...
# Company: Journey Energy Inc. Ticker: JOY.TO
# sector: Energy
#
# Processing row 425...
# Company: K-Bro Linen Inc. Ticker: KBL.TO
# sector: Industrials
#
# Processing row 426...
# Company: K92 Mining Inc. Ticker: KNT.TO
# sector: Basic Materials
#
# Processing row 427...
# Company: Karnalyte Resources Inc. Ticker: KRN.TO
# sector: Basic Materials
#
# Processing row 428...
# Company: Karora Resources Inc. Ticker: KRR.TO
# sector: Basic Materials
#
# Processing row 429...
# Company: Kelso Technologies Inc. Ticker: KLS.TO
# sector: Industrials
#
# Processing row 430...
# Company: Kelt Exploration Ltd. Ticker: KEL.TO
# sector: Energy
#
# Processing row 431...
# Company: Keyera Corp. Ticker: KEY.TO
# sector: Energy
#
# Processing row 432...
# Company: Kinaxis Inc. Ticker: KXS.TO
# sector: Technology
#
# Processing row 433...
# Company: Kinross Gold Corporation Ticker: K.TO
# sector: Basic Materials
#
# Processing row 434...
# Company: Kits Eyecare Ltd. Ticker: KITS.TO
# sector: Consumer Cyclical
#
# Processing row 435...
# Company: Kiwetinohk Energy Corp. Ticker: KEC.TO
# sector: Energy
#
# Processing row 436...
# Company: kneat.com, inc. Ticker: KSI.TO
# sector: Healthcare
#
# Processing row 437...
# Company: Knight Therapeutics Inc. Ticker: GUD.TO
# sector: Healthcare
#
# Processing row 438...
# Company: Kolibri Global Energy Inc. Ticker: KEI.TO
# sector: Energy
#
# Processing row 439...
# Company: KP Tissue Inc. Ticker: KPT.TO
# sector: Consumer Defensive
#
# Processing row 440...
# Company: Brompton Lifeco Split Corp. Ticker: LCS.TO
# sector: Financial Services
#
# Processing row 441...
# Company: Canadian Life Companies Split Corp. Ticker: LFE.TO
# sector: Financial Services
#
# Processing row 442...
# Company: Labrador Iron Ore Royalty Corporation Ticker: LIF.TO
# sector: Basic Materials
#
# Processing row 443...
# Company: Laramide Resources Ltd. Ticker: LAM.TO
# sector: Energy
#
# Processing row 444...
# Company: Largo Inc. Ticker: LGO.TO
# sector: Basic Materials
#
# Processing row 445...
# Company: Lassonde Industries Inc. Ticker: LAS-A.TO
# sector: Consumer Defensive
#
# Processing row 446...
# Company: Laurentian Bank of Canada Ticker: LB.TO
# sector: Financial Services
#
# Processing row 447...
# Company: Leon's Furniture Limited Ticker: LNF.TO
# sector: Consumer Cyclical
#
# Processing row 448...
# Company: Liberty Gold Corp. Ticker: LGD.TO
# sector: Basic Materials
#
# Processing row 449...
# Company: Life & Banc Split Corp. Ticker: LBS.TO
# sector: Financial Services
#
# Processing row 450...
# Company: LifeSpeak Inc. Ticker: LSPK.TO
# sector: Technology
#
# Processing row 451...
# Company: Lightspeed Commerce Inc. Ticker: LSPD.TO
# sector: Technology
#
# Processing row 452...
# Company: Linamar Corporation Ticker: LNR.TO
# sector: Consumer Cyclical
#
# Processing row 453...
# Company: The Lion Electric Company Ticker: LEV.TO
# sector: Industrials
#
# Processing row 454...
# Company: Lithium Americas (Argentina) Corp. Ticker: LAAC.TO
# sector: Basic Materials
#
# Processing row 455...
# Company: Lithium Americas Corp. Ticker: LAC.TO
# sector: Basic Materials
#
# Processing row 456...
# Company: Lithium Royalty Corp. Ticker: LIRC.TO
# sector: Basic Materials
#
# Processing row 457...
# Company: Loblaw Companies Limited Ticker: L.TO
# sector: Consumer Defensive
#
# Processing row 458...
# Company: Loncor Gold Inc. Ticker: LN.TO
# sector: Basic Materials
#
# Processing row 459...
# Company: Loop Energy Inc. Ticker: LPEN.TO
# sector: Industrials
#
# Processing row 460...
# Company: Lucara Diamond Corp. Ticker: LUC.TO
# sector: Basic Materials
#
# Processing row 461...
# Company: Lundin Gold Inc. Ticker: LUG.TO
# sector: Basic Materials
#
# Processing row 462...
# Company: Lundin Mining Corporation Ticker: LUN.TO
# sector: Basic Materials
#
# Processing row 463...
# Company: MediPharm Labs Corp. Ticker: LABS.TO
# sector: Healthcare
#
# Processing row 464...
# Company: Tidewater Renewables Ltd. Ticker: LCFS.TO
# sector: Utilities
#
# Processing row 465...
# Company: Excelsior Mining Corp. Ticker: MIN.TO
# sector: Basic Materials
#
# Processing row 466...
# Company: M Split Corp. Ticker: XMF-A.TO
# sector: Financial Services
#
# Processing row 467...
# Company: Mackenzie Master Limited Partnership Ticker: MKZ-UN.TO
# sector: Financial Services
#
# Processing row 468...
# Company: Madison Pacific Properties Inc. Ticker: MPC-C.TO
# sector: Real Estate
#
# Processing row 469...
# Company: MAG Silver Corp. Ticker: MAG.TO
# sector: Basic Materials
#
# Processing row 470...
# Company: Magellan Aerospace Corporation Ticker: MAL.TO
# sector: Industrials
#
# Processing row 471...
# Company: Magna International Inc. Ticker: MG.TO
# sector: Consumer Cyclical
#
# Processing row 472...
# Company: Mainstreet Equity Corp. Ticker: MEQ.TO
# sector: Real Estate
#
# Processing row 473...
# Company: Major Drilling Group International Inc. Ticker: MDI.TO
# sector: Basic Materials
#
# Processing row 474...
# Company: Mandalay Resources Corporation Ticker: MND.TO
# sector: Basic Materials
#
# Processing row 475...
# Company: Manulife Financial Corporation Ticker: MFC.TO
# sector: Financial Services
#
# Processing row 476...
# Company: Maple Leaf Foods Inc. Ticker: MFI.TO
# sector: Consumer Defensive
#
# Processing row 477...
# Company: Marimaca Copper Corp. Ticker: MARI.TO
# sector: Basic Materials
#
# Processing row 478...
# Company: Martinrea International Inc. Ticker: MRE.TO
# sector: Consumer Cyclical
#
# Processing row 479...
# Company: Mattr Corp. Ticker: MATR.TO
# sector: Energy
#
# Processing row 480...
# Company: Maxim Power Corp. Ticker: MXG.TO
# sector: Utilities
#
# Processing row 481...
# Company: MCAN Mortgage Corporation Ticker: MKP.TO
# sector: Financial Services
#
# Processing row 482...
# Company: McCoy Global Inc. Ticker: MCB.TO
# sector: Energy
#
# Processing row 483...
# Company: McEwen Mining Inc. Ticker: MUX.TO
# sector: Basic Materials
#
# Processing row 484...
# Company: MDA Ltd. Ticker: MDA.TO
# sector: Industrials
#
# Processing row 485...
# Company: mdf commerce inc. Ticker: MDF.TO
# sector: Technology
#
# Processing row 486...
# Company: Medexus Pharmaceuticals Inc. Ticker: MDP.TO
# sector: Healthcare
#
# Processing row 487...
# Company: MediaValet Inc. Ticker: MVP.TO
# sector: Technology
#
# Processing row 488...
# Company: Medical Facilities Corporation Ticker: DR.TO
# sector: Healthcare
#
# Processing row 489...
# Company: Medicenna Therapeutics Corp. Ticker: MDNA.TO
# sector: Healthcare
#
# Processing row 490...
# Company: MediPharm Labs Corp. Ticker: LABS.TO
# sector: Healthcare
#
# Processing row 491...
# Company: MEG Energy Corp. Ticker: MEG.TO
# sector: Energy
#
# Processing row 492...
# Company: Mega Uranium Ltd. Ticker: MGA.TO
# sector: Energy
#
# Processing row 493...
# Company: Melcor Developments Ltd. Ticker: MRD.TO
# sector: Real Estate
#
# Processing row 494...
# Company: Meridian Mining UK Societas Ticker: MNO.TO
# sector: Basic Materials
#
# Processing row 495...
# Company: Methanex Corporation Ticker: MX.TO
# sector: Basic Materials
#
# Processing row 496...
# Company: Metro Inc. Ticker: MRU.TO
# sector: Consumer Defensive
#
# Processing row 497...
# Company: Microbix Biosystems Inc. Ticker: MBX.TO
# sector: Healthcare
#
# Processing row 498...
# Company: Minco Silver Corporation Ticker: MSV.TO
# sector: Basic Materials
#
# Processing row 499...
# Company: Mineros S.A. Ticker: MSA.TO
# sector: Basic Materials
#
# Processing row 500...
# Company: Mogo Inc. Ticker: MOGO.TO
# sector: Technology
#
# Processing row 501...
# Company: Molson Coors Canada Inc. Ticker: TPX-B.TO
# sector: Consumer Defensive
#
# Processing row 502...
# Company: Moneta Gold Inc. Ticker: ME.TO
# sector: Basic Materials
#
# Processing row 503...
# Company: Morguard Corporation Ticker: MRC.TO
# sector: Real Estate
#
# Processing row 504...
# Company: Mountain Province Diamonds Inc. Ticker: MPVD.TO
# sector: Basic Materials
#
# Processing row 505...
# Company: MTY Food Group Inc. Ticker: MTY.TO
# sector: Consumer Cyclical
#
# Processing row 506...
# Company: Mullen Group Ltd. Ticker: MTL.TO
# sector: Industrials
#
# Processing row 507...
# Company: Royal Canadian Mint - Canadian Gold Reserves Ticker: MNT.TO
# Error processing row 507: 'legalType'
# Processing row 508...
# ...
# sector: Industrials
#
# Processing row 649...
# Company: Sentry Select Primary Metals Corp. Ticker: PME.TO
# Error processing row 649: 'legalType'
# Processing row 650...
# Company: Senvest Capital Inc. Ticker: SEC.TO
# sector: Financial Services
#
# Processing row 651...
# Company: Serabi Gold plc Ticker: SRB.L
# sector: Basic Materials
#
# Processing row 652...
# Company: Sernova Corp. Ticker: SVA.TO
# sector: Healthcare
#
# Processing row 653...
# Company: Sherritt International Corporation Ticker: S.TO
# sector: Basic Materials
#
# Processing row 654...
# Company: Shopify Inc. Ticker: SHOP.TO
# sector: Technology
#
# Processing row 655...
# Company: Sienna Senior Living Inc. Ticker: SIA.TO
# sector: Healthcare
#
# Processing row 656...
# Company: Sierra Metals Inc. Ticker: SMT.TO
# sector: Basic Materials
#
# Processing row 657...
# Company: Signal Gold Inc. Ticker: SGNL.TO
# sector: Basic Materials
#
# Processing row 658...
# Company: Silver Bear Resources Plc Ticker: SBR.TO
# sector: Basic Materials
#
# Processing row 659...
# Company: Silver Bull Resources, Inc. Ticker: SVB.TO
# sector: Basic Materials
#
# Processing row 660...
# Company: Silver Elephant Mining Corp. Ticker: ELEF.TO
# sector: Basic Materials
#
# Processing row 661...
# Company: Silvercorp Metals Inc. Ticker: SVM.TO
# sector: Basic Materials
#
# Processing row 662...
# Company: SilverCrest Metals Inc. Ticker: SIL.TO
# sector: Basic Materials
#
# Processing row 663...
# Company: Skeena Resources Limited Ticker: SKE.TO
# sector: Basic Materials
#
# Processing row 664...
# Company: Slate Grocery REIT Ticker: SGR-UN.TO
# sector: Real Estate
#
# Processing row 665...
# Company: Slate Office REIT Ticker: SOT-UN.TO
# sector: Real Estate
#
# Processing row 666...
# Company: Sleep Country Canada Holdings Inc. Ticker: ZZZ.TO
# sector: Consumer Cyclical
#
# Processing row 667...
# Company: SNC-Lavalin Group Inc. Ticker: ATRL.TO
# sector: Industrials
#
# Processing row 668...
# Company: Softchoice Corporation Ticker: SFTC.TO
# sector: Technology
#
# Processing row 669...
# Company: Solaris Resources Inc. Ticker: SLS.TO
# sector: Basic Materials
#
# Processing row 670...
# Company: SolGold Plc Ticker: SOLG.TO
# sector: Basic Materials
#
# Processing row 671...
# Company: Solitario Resources Corp. Ticker: XPL
# sector: Basic Materials
#
# Processing row 672...
# Company: Solution Financial Inc. Ticker: SFI.TO
# sector: Industrials
#
# Processing row 673...
# Company: Source Energy Services Ltd. Ticker: SHLE.TO
# sector: Energy
#
# Processing row 674...
# Company: Spartan Delta Corp. Ticker: SDE.TO
# sector: Energy
#
# Processing row 675...
# Company: Spectral Medical Inc. Ticker: EDT.TO
# sector: Healthcare
#
# Processing row 676...
# Company: Spin Master Corp. Ticker: TOY.TO
# sector: Consumer Cyclical
#
# Processing row 677...
# Company: Sprott Inc. Ticker: SII.TO
# sector: Financial Services
#
# Processing row 678...
# Company: SSR Mining Inc. Ticker: SSRM.TO
# sector: Basic Materials
#
# Processing row 679...
# Company: St. Augustine Gold and Copper Limited Ticker: SAU.TO
# sector: Basic Materials
#
# Processing row 680...
# Company: Stack Capital Group Inc. Ticker: STCK.TO
# sector: Financial Services
#
# Processing row 681...
# Company: StageZero Life Sciences Ltd. Ticker: SZLS.TO
# sector: Healthcare
#
# Processing row 682...
# Company: Stantec Inc. Ticker: STN.TO
# sector: Industrials
#
# Processing row 683...
# Company: Star Diamond Corporation Ticker: DIAM.TO
# sector: Basic Materials
#
# Processing row 684...
# Company: Starcore International Mines Ltd. Ticker: SAM.TO
# sector: Basic Materials
#
# Processing row 685...
# Company: Stelco Holdings Inc. Ticker: STLC.TO
# sector: Basic Materials
#
# Processing row 686...
# Company: Stella-Jones Inc. Ticker: SJ.TO
# sector: Basic Materials
#
# Processing row 687...
# Company: STEP Energy Services Ltd. Ticker: STEP.TO
# sector: Energy
#
# Processing row 688...
# Company: Steppe Gold Ltd. Ticker: STGO.TO
# sector: Basic Materials
#
# Processing row 689...
# Company: Stingray Group Inc. Ticker: RAY-A.TO
# sector: Communication Services
#
# Processing row 690...
# Company: StorageVault Canada Inc. Ticker: SVI.TO
# sector: Real Estate
#
# Processing row 691...
# Company: Strathcona Resources Ltd. Ticker: SCR.TO
# sector: Energy
#
# Processing row 692...
# Company: Sulliden Mining Capital Inc. Ticker: SMC.TO
# sector: Basic Materials
#
# Processing row 693...
# Company: Sun Life Financial Inc. Ticker: SLF.TO
# sector: Financial Services
#
# Processing row 694...
# Company: Suncor Energy Inc. Ticker: SU.TO
# sector: Energy
#
# Processing row 695...
# Company: SunOpta Inc. Ticker: SOY.TO
# sector: Consumer Defensive
#
# Processing row 696...
# Company: Superior Plus Corp. Ticker: SPB.TO
# sector: Utilities
#
# Processing row 697...
# Company: Supremex Inc. Ticker: SXP.TO
# sector: Consumer Cyclical
#
# Processing row 698...
# Company: Surge Energy Inc. Ticker: SGY.TO
# sector: Energy
#
# Processing row 699...
# Company: Sustainable Power & Infrastructure Split Corp. Ticker: PWI.TO
# sector: Financial Services
#
# Processing row 700...
# Company: Swiss Water Decaffeinated Coffee Inc. Ticker: SWP.TO
# sector: Consumer Defensive
#
# Processing row 701...
# Company: Sylogist Ltd. Ticker: SYZ.TO
# sector: Technology
#
# Processing row 702...
# Company: Synex Renewable Energy Corporation Ticker: SXI.TO
# sector: Utilities
#
# Processing row 703...
# Company: Molson Coors Canada Inc. Ticker: TPX-B.TO
# sector: Consumer Defensive
#
# Processing row 704...
# Company: PetroTal Corp. Ticker: TAL.TO
# sector: Energy
#
# Processing row 705...
# Company: Spin Master Corp. Ticker: TOY.TO
# sector: Consumer Cyclical
#
# Processing row 706...
# Company: Taiga Building Products Ltd. Ticker: TBL.TO
# sector: Basic Materials
#
# Processing row 707...
# Company: Taiga Motors Corporation Ticker: TAIG.TO
# sector: Consumer Cyclical
#
# Processing row 708...
# Company: Talisker Resources Ltd. Ticker: TSK.TO
# sector: Basic Materials
#
# Processing row 709...
# Company: Talon Metals Corp. Ticker: TLO.TO
# sector: Basic Materials
#
# Processing row 710...
# Company: Tamarack Valley Energy Ltd. Ticker: TVE.TO
# sector: Energy
#
# Processing row 711...
# Company: Tantalus Systems Holding Inc. Ticker: GRID.TO
# sector: Industrials
#
# Processing row 712...
# Company: Taseko Mines Limited Ticker: TKO.TO
# sector: Basic Materials
#
# Processing row 713...
# Company: TC Energy Corporation Ticker: TRP.TO
# sector: Energy
#
# Processing row 714...
# Company: TDb Split Corp. Ticker: XTD.TO
# sector: Financial Services
#
# Processing row 715...
# Company: Teck Resources Limited Ticker: TECK-B.TO
# sector: Basic Materials
#
# Processing row 716...
# Company: Tecsys Inc. Ticker: TCS.TO
# sector: Technology
#
# Processing row 717...
# Company: Telesat Corporation Ticker: TSAT.TO
# sector: Technology
#
# Processing row 718...
# Company: TELUS Corporation Ticker: T.TO
# sector: Communication Services
#
# Processing row 719...
# Company: TELUS International (Cda) Inc. Ticker: TIXT.TO
# sector: Technology
#
# Processing row 720...
# Company: Tenaz Energy Corp. Ticker: TNZ.TO
# sector: Energy
#
# Processing row 721...
# Company: TeraGo Inc. Ticker: TGO.TO
# sector: Communication Services
#
# Processing row 722...
# Company: TerrAscend Corp. Ticker: TSND.TO
# sector: Healthcare
#
# Processing row 723...
# Company: TerraVest Industries Inc. Ticker: TVK.TO
# sector: Energy
#
# Processing row 724...
# Company: TFI International Inc. Ticker: TFII.TO
# sector: Industrials
#
# Processing row 725...
# Company: Theratechnologies Inc. Ticker: TH.TO
# sector: Healthcare
#
# Processing row 726...
# Company: Thinkific Labs Inc. Ticker: THNC.TO
# sector: Technology
#
# Processing row 727...
# Company: Thomson Reuters Corporation Ticker: TRI.TO
# sector: Industrials
#
# Processing row 728...
# Company: Tidewater Midstream and Infrastructure Ltd. Ticker: TWM.TO
# sector: Energy
#
# Processing row 729...
# Company: Tidewater Renewables Ltd. Ticker: LCFS.TO
# sector: Utilities
#
# Processing row 730...
# Company: Tilray Brands, Inc. Ticker: TLRY.TO
# sector: Healthcare
#
# Processing row 731...
# Company: Timbercreek Financial Corp. Ticker: TF.TO
# sector: Financial Services
#
# Processing row 732...
# Company: Titan Medical Inc. Ticker: TMD.TO
# sector: Healthcare
#
# Processing row 733...
# Company: Titan Mining Corporation Ticker: TI.TO
# sector: Basic Materials
#
# Processing row 734...
# Company: Titanium Transportation Group Inc. Ticker: TTNMF
# sector: Industrials
#
# Processing row 735...
# Company: TMX Group Limited Ticker: X.TO
# sector: Financial Services
#
# Processing row 736...
# Company: Topaz Energy Corp. Ticker: TPZ.TO
# sector: Energy
#
# Processing row 737...
# Company: Torex Gold Resources Inc. Ticker: TXG.TO
# sector: Basic Materials
#
# Processing row 738...
# Company: Toromont Industries Ltd. Ticker: TIH.TO
# sector: Industrials
#
# Processing row 739...
# Company: The Toronto-Dominion Bank Ticker: TD.TO
# sector: Financial Services
#
# Processing row 740...
# Company: Total Energy Services Inc. Ticker: TOT.TO
# sector: Energy
#
# Processing row 741...
# Company: Touchstone Exploration Inc. Ticker: TXP.TO
# sector: Energy
#
# Processing row 742...
# Company: Tourmaline Oil Corp. Ticker: TOU.TO
# sector: Energy
#
# Processing row 743...
# Company: TransAlta Corporation Ticker: TA.TO
# sector: Utilities
#
# Processing row 744...
# Company: Transat A.T. Inc. Ticker: TRZ.TO
# sector: Consumer Cyclical
#
# Processing row 745...
# Company: Transcontinental Inc. Ticker: TCL-A.TO
# sector: Consumer Cyclical
#
# Processing row 746...
# Company: Treasury Metals Inc. Ticker: TML.TO
# sector: Basic Materials
#
# Processing row 747...
# Company: Tree Island Steel Ltd. Ticker: TSL.TO
# sector: Basic Materials
#
# Processing row 748...
# Company: Trican Well Service Ltd. Ticker: TCW.TO
# sector: Energy
#
# Processing row 749...
# Company: Tricon Residential Inc. Ticker: TCN.TO
# sector: Real Estate
#
# Processing row 750...
# Company: Trilogy Metals Inc. Ticker: TMQ.TO
# sector: Basic Materials
#
# Processing row 751...
# Company: Triple Flag Precious Metals Corp. Ticker: TFPM.TO
# sector: Basic Materials
#
# Processing row 752...
# Company: Trisura Group Ltd. Ticker: TSU.TO
# sector: Financial Services
#
# Processing row 753...
# Company: Troilus Gold Corp. Ticker: TLG.TO
# sector: Basic Materials
#
# Processing row 754...
# Company: TRX Gold Corporation Ticker: TRX
# sector: Basic Materials
#
# Processing row 755...
# Company: Tucows Inc. Ticker: TC.TO
# sector: Technology
#
# Processing row 756...
# Company: TVA Group Inc. Ticker: TVA-B.TO
# sector: Communication Services
#
# Processing row 757...
# Company: TWC Enterprises Limited Ticker: TWC.TO
# sector: Consumer Cyclical
#
# Processing row 758...
# Company: Americas Gold and Silver Corporation Ticker: USA.TO
# sector: Basic Materials
#
# Processing row 759...
# Company: Unisync Corp. Ticker: UNI.TO
# sector: Consumer Cyclical
#
# Processing row 760...
# Company: United Corporations Limited Ticker: UNC.TO
# sector: Financial Services
#
# Processing row 761...
# Company: Ur-Energy Inc. Ticker: URE.TO
# sector: Energy
#
# Processing row 762...
# Company: Uranium Royalty Corp. Ticker: URC.TO
# sector: Energy
#
# Processing row 763...
# Company: Urbana Corporation Ticker: URB.TO
# sector: Financial Services
#
# Processing row 764...
# Company: US Financial 15 Split Corp Ticker: FTU.TO
# sector: Financial Services
#
# Processing row 765...
# Company: 5N Plus Inc. Ticker: VNP.TO
# sector: Basic Materials
#
# Processing row 766...
# Company: Gamelancer Media Corp. Ticker: GAMGF
# sector: Communication Services
#
# Processing row 767...
# Company: Valeo Pharma Inc. Ticker: VPH.TO
# sector: Healthcare
#
# Processing row 768...
# Company: Valeura Energy Inc. Ticker: VLE.TO
# sector: Energy
#
# Processing row 769...
# Company: Vecima Networks Inc. Ticker: VCM.TO
# sector: Technology
#
# Processing row 770...
# Company: Velan Inc. Ticker: VLN.TO
# sector: Industrials
#
# Processing row 771...
# Company: Verde AgriTech Limited Ticker: NPK.TO
# sector: Basic Materials
#
# Processing row 772...
# Company: Vermilion Energy Inc. Ticker: VET.TO
# sector: Energy
#
# Processing row 773...
# Company: VersaBank Ticker: VBNK.TO
# sector: Financial Services
#
# Processing row 774...
# Company: VerticalScope Holdings Inc. Ticker: FORA.TO
# sector: Communication Services
#
# Processing row 775...
# Company: Victoria Gold Corp. Ticker: VGCX.TO
# sector: Basic Materials
#
# Processing row 776...
# Company: VIQ Solutions Inc. Ticker: VQS.TO
# sector: Technology
#
# Processing row 777...
# Company: Vista Gold Corp. Ticker: VGZ.TO
# sector: Basic Materials
#
# Processing row 778...
# Company: Vitalhub Corp. Ticker: VHI.TO
# sector: Healthcare
#
# Processing row 779...
# Company: VM Hotel Acquisition Corp. Ticker: VMH-U.TO
# sector: Financial Services
#
# Processing row 780...
# Company: Vox Royalty Corp. Ticker: VOXR
# sector: Basic Materials
#
# Processing row 781...
# Company: Canopy Growth Corporation Ticker: WEED.TO
# sector: Healthcare
#
# Processing row 782...
# Company: George Weston Limited Ticker: WN.TO
# sector: Consumer Defensive
#
# Processing row 783...
# Company: Wajax Corporation Ticker: WJX.TO
# sector: Industrials
#
# Processing row 784...
# Company: Wall Financial Corporation Ticker: WFC.TO
# sector: Real Estate
#
# Processing row 785...
# Company: Wallbridge Mining Company Limited Ticker: WM.TO
# sector: Basic Materials
#
# Processing row 786...
# Company: Waste Connections, Inc. Ticker: WCN.TO
# sector: Industrials
#
# Processing row 787...
# Company: WELL Health Technologies Corp. Ticker: WELL.TO
# sector: Healthcare
#
# Processing row 788...
# Company: Wesdome Gold Mines Ltd. Ticker: WDO.TO
# sector: Basic Materials
#
# Processing row 789...
# Company: West Fraser Timber Co. Ltd. Ticker: WFG.TO
# sector: Basic Materials
#
# Processing row 790...
# Company: Western Copper and Gold Corporation Ticker: WRN.TO
# sector: Basic Materials
#
# Processing row 791...
# Company: Western Energy Services Corp. Ticker: WRG.TO
# sector: Energy
#
# Processing row 792...
# Company: Western Forest Products Inc. Ticker: WEF.TO
# sector: Basic Materials
#
# Processing row 793...
# Company: Western Resources Corp. Ticker: WRX.TO
# sector: Basic Materials
#
# Processing row 794...
# Company: Westport Fuel Systems Inc. Ticker: WPRT.TO
# sector: Consumer Cyclical
#
# Processing row 795...
# Company: Westshore Terminals Investment Corporation Ticker: WTE.TO
# sector: Industrials
#
# Processing row 796...
# Company: Wheaton Precious Metals Corp. Ticker: WPM.TO
# sector: Basic Materials
#
# Processing row 797...
# Company: Whitecap Resources Inc. Ticker: WCP.TO
# sector: Energy
#
# Processing row 798...
# Company: WildBrain Ltd. Ticker: WILD.TO
# sector: Communication Services
#
# Processing row 799...
# Company: Willow Biosciences Inc. Ticker: WLLW.TO
# sector: Healthcare
#
# Processing row 800...
# Company: Wilmington Capital Management Inc. Ticker: WCM-B.TO
# sector: Financial Services
#
# Processing row 801...
# Company: Winpak Ltd. Ticker: WPK.TO
# sector: Consumer Cyclical
#
# Processing row 802...
# Company: WonderFi Technologies Inc. Ticker: WNDR.TO
# sector: Technology
#
# Processing row 803...
# Company: World Financial Split Corp. Ticker: WFS.TO
# Error processing row 803: 'legalType'
# Processing row 804...
# Company: WSP Global Inc. Ticker: WSP.TO
# sector: Industrials
#
# Processing row 805...
# Company: Auxly Cannabis Group Inc. Ticker: XLY.TO
# sector: Healthcare
#
# Processing row 806...
# Company: Exco Technologies Limited Ticker: XTC.TO
# sector: Consumer Cyclical
#
# Processing row 807...
# Company: Goldmoney Inc. Ticker: XAU.TO
# sector: Financial Services
#
# Processing row 808...
# Company: M Split Corp. Ticker: XMF-A.TO
# sector: Financial Services
#
# Processing row 809...
# Company: TDb Split Corp. Ticker: XTD.TO
# sector: Financial Services
#
# Processing row 810...
# Company: TMX Group Limited Ticker: X.TO
# sector: Financial Services
#
# Processing row 811...
# Company: Xanadu Mines Limited Ticker: XAM.TO
# sector: Basic Materials
#
# Processing row 812...
# Company: Xtra-Gold Resources Corp. Ticker: XTG.TO
# sector: Basic Materials
#
# Processing row 813...
# Company: Xtract One Technologies Inc. Ticker: XTRA.TO
# sector: Technology
#
# Processing row 814...
# Company: Commerce Split Corp Ticker: YCM-PA.TO
# Error processing row 814: 'legalType'
# Processing row 815...
# Company: Yangarra Resources Ltd. Ticker: YGR.TO
# sector: Energy
#
# Processing row 816...
# Company: Yellow Pages Limited Ticker: Y.TO
# sector: Communication Services
#
# Processing row 817...
# Company: Yorbeau Resources Inc. Ticker: YRB.TO
# sector: Basic Materials
#
# Processing row 818...
# Company: Sleep Country Canada Holdings Inc. Ticker: ZZZ.TO
# sector: Consumer Cyclical
#
# Processing row 819...
# Company: 5N Plus Inc. Ticker: VNP.TO
# sector: Basic Materials
#
# Processing row 820...
# Company: First National Financial Corporation Ticker: FN.TO
# sector: Financial Services

# %%
# Create a new DataFrame without rows where Ticker is None
TSX_Data = TSX_Data.dropna().drop_duplicates(subset=['Ticker']).reset_index(drop=True)
TSX_Data
# Out:
#       Ticker                       Company                  Sector  \
# 0     AAB.TO   Aberdeen International Inc.      Financial Services
# 1     ADN.TO          Acadian Timber Corp.         Basic Materials
# 2     ACD.TO        Accord Financial Corp.      Financial Services
# 3     ARA.TO         Aclara Resources Inc.         Basic Materials
# 4    ADCO.TO                   Adcore Inc.              Technology
# ..       ...                           ...                     ...
# 708   XAM.TO          Xanadu Mines Limited         Basic Materials
# 709   XTG.TO     Xtra-Gold Resources Corp.         Basic Materials
# 710  XTRA.TO  Xtract One Technologies Inc.              Technology
# 711     Y.TO          Yellow Pages Limited  Communication Services
# 712   YRB.TO        Yorbeau Resources Inc.         Basic Materials
#
#     Revenue_2022 Revenue_2021 Revenue_2020
# 0     -8762676.0    9139536.0    5628492.0
# 1     90473000.0   95729000.0   91031000.0
# 2     43403627.0   47593755.0   33904916.0
# 3            0.0          0.0          0.0
# 4     19693000.0   27966000.0   16997000.0
# ..           ...          ...          ...
# 708          N/A          N/A          N/A
# 709          0.0          0.0          0.0
# 710    4111244.0    3619214.0    1081975.0
# 711  268278000.0  287646000.0  333538000.0
# 712     596841.0     820893.0     817736.0
#
# [713 rows x 6 columns]

# %%
# Save the shrunk dataset to a new CSV file
TSX_Data.to_csv('/content/drive/MyDrive/Colab Notebooks/data/TSX_Companies_yf.csv', index=False, sep=',')

# Provide a download link for the file
from google.colab import files
files.download('/content/drive/MyDrive/Colab Notebooks/data/TSX_Companies_yf.csv')

# %% [markdown]
# #Graphing the industries

# %%
import pandas as pd
import plotly.express as px
import numpy as np

# Convert revenue columns to numeric format, replacing non-numeric values with NaN
TSX_Data['Revenue_2020'] = pd.to_numeric(TSX_Data['Revenue_2020'], errors='coerce')
TSX_Data['Revenue_2021'] = pd.to_numeric(TSX_Data['Revenue_2021'], errors='coerce')
TSX_Data['Revenue_2022'] = pd.to_numeric(TSX_Data['Revenue_2022'], errors='coerce')

# Divide revenue by 1,000,000 to convert to millions
TSX_Data['Revenue_2020'] /= 1_000_000
TSX_Data['Revenue_2021'] /= 1_000_000
TSX_Data['Revenue_2022'] /= 1_000_000

# Group the data by 'Sector' and calculate total revenue for each sector
sector_revenue = TSX_Data.groupby('Sector')[['Revenue_2022']].sum()

# Reset index to make 'Sector' a column again
sector_revenue = sector_revenue.reset_index()

# Create a bar plot using Plotly
fig = px.bar(sector_revenue, x='Sector', y='Revenue_2022',
             title='Total Revenue in 2022 by Sector (in Millions)',
             labels={'Revenue_2022': 'Revenue (Millions)', 'Sector': 'Sector'},
             color='Sector')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8050fa52-9a09-4b84-ad48-3d5d9d1dfcea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8050fa52-9a09-4b84-ad48-3d5d9d1dfcea")) {                    Plotly.newPlot(                        "8050fa52-9a09-4b84-ad48-3d5d9d1dfcea",                        [{"alignmentgroup":"True","hovertemplate":"Sector=%{x}\u003cbr\u003eRevenue (Millions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Basic Materials","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Basic Materials","offsetgroup":"Basic Materials","orientation":"v","showlegend":true,"textposition":"auto","x":["Basic Materials"],"xaxis":"x","y":[1.77934394684e-07],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sector=%{x}\u003cbr\u003eRevenue (Millions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Communication Services","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Communication Services","offsetgroup":"Communication Services","orientation":"v","showlegend":true,"textposition":"auto","x":["Communication Services"],"xaxis":"x","y":[7.1326407013e-08],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sector=%{x}\u003cbr\u003eRevenue (Millions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Consumer Cyclical","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Consumer Cyclical","offsetgroup":"Consumer Cyclical","orientation":"v","showlegend":true,"textposition":"auto","x":["Consumer Cyclical"],"xaxis":"x","y":[2.1384079631299997e-07],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sector=%{x}\u003cbr\u003eRevenue (Millions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Consumer Defensive","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Consumer Defensive","offsetgroup":"Consumer Defensive","orientation":"v","showlegend":true,"textposition":"auto","x":["Consumer Defensive"],"xaxis":"x","y":[2.22061136893e-07],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sector=%{x}\u003cbr\u003eRevenue (Millions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Energy","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Energy","offsetgroup":"Energy","orientation":"v","showlegend":true,"textposition":"auto","x":["Energy"],"xaxis":"x","y":[4.93320624358e-07],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sector=%{x}\u003cbr\u003eRevenue (Millions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Exchange Traded Fund","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Exchange Traded Fund","offsetgroup":"Exchange Traded Fund","orientation":"v","showlegend":true,"textposition":"auto","x":["Exchange Traded Fund"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sector=%{x}\u003cbr\u003eRevenue (Millions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Financial Services","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Financial Services","offsetgroup":"Financial Services","orientation":"v","showlegend":true,"textposition":"auto","x":["Financial Services"],"xaxis":"x","y":[5.15206515097e-07],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sector=%{x}\u003cbr\u003eRevenue (Millions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Healthcare","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Healthcare","offsetgroup":"Healthcare","orientation":"v","showlegend":true,"textposition":"auto","x":["Healthcare"],"xaxis":"x","y":[2.2575646422999998e-08],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sector=%{x}\u003cbr\u003eRevenue (Milli ...
